# %% [markdown]
# ![logo%20MIOTI%20g.png](attachment:logo%20MIOTI%20g.png)

# %% [markdown]
# # Como usar Data Science para invertir en Bolsa

# %% [markdown]
# ## Demostración Creación de un Algo Trader

# %% [markdown]
# Librerias que tenemos que instalar para el correcto funcionamiento del notebook.

# %%
# !pip install -U pandas_datareader tqdm tensorflow
# Out:
# Requirement already satisfied: pandas_datareader in c:\users\usuario\.conda\envs\finance\lib\site-packages (0.10.0)
# Requirement already satisfied: tqdm in c:\users\usuario\.conda\envs\finance\lib\site-packages (4.62.3)
# Requirement already satisfied: tensorflow in c:\users\usuario\.conda\envs\finance\lib\site-packages (2.7.0)
# Requirement already satisfied: lxml in c:\users\usuario\.conda\envs\finance\lib\site-packages (from pandas_datareader) (4.6.4)
# Requirement already satisfied: pandas>=0.23 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from pandas_datareader) (1.1.5)
# Requirement already satisfied: requests>=2.19.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from pandas_datareader) (2.26.0)
# Requirement already satisfied: colorama in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tqdm) (0.4.4)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (0.22.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (12.0.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (0.13.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (2.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (3.17.2)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from pandas>=0.23->pandas_datareader) (2021.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.0.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorboard~=2.6->tensorflow) (58.0.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.4.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.33.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.0.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.6.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\usuario\.conda\envs\finance\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)

# %%
import math
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data_reader
from tqdm import tqdm_notebook as tqdm
from tqdm.keras import TqdmCallback
# %matplotlib inline
import mplfinance as mpf
import tensorflow as tf

# %% [markdown]
# ## 1.2 Crear el Dataset

# %% [markdown]
# Definimos una función que utilizando la librería `pandas_datareader` descargaremos de yahoo las cotizaciones de los activos que queremos modelizar.

# %%
def dataset_loader(stock_name,start_date=None,end_date=None):
  
    dataset = data_reader.DataReader(stock_name, 
                                   data_source="yahoo",
                                   start=start_date,
                                   end=end_date)
    return dataset

# %% [markdown]
# Hacemos una prueba cargando el valor de una acción (en este caso APPLE cuyo id es AAPL)

# %%
#stock='BBVA'
#stock='IBM'
#stock='TSLA'
stock='GOOGL'
#stock='AMZN'
#stock='WMT'
#stock='TEF'
df=dataset_loader(stock,start_date='2015-01-01')
df
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2015-01-02   535.799988   527.880005   532.599976   529.549988  1324000
# 2015-01-05   527.989990   517.750000   527.150024   519.460022  2059100
# 2015-01-06   521.210022   505.549988   520.500000   506.640015  2722800
# 2015-01-07   511.489990   503.649994   510.950012   505.149994  2345900
# 2015-01-08   507.500000   495.019989   501.510010   506.910004  3652700
# ...                 ...          ...          ...          ...      ...
# 2021-11-18  3011.610107  2957.689941  2964.830078  2996.770020  1780400
# 2021-11-19  3019.330078  2977.979980  2999.510010  2978.530029  1684100
# 2021-11-22  2996.590088  2922.949951  2986.649902  2926.040039  1529700
# 2021-11-23  2933.199951  2882.300049  2923.060059  2915.639893  1360900
# 2021-11-24  2924.989990  2887.459961  2909.469971  2922.399902   900900
#
#               Adj Close
# Date
# 2015-01-02   529.549988
# 2015-01-05   519.460022
# 2015-01-06   506.640015
# 2015-01-07   505.149994
# 2015-01-08   506.910004
# ...                 ...
# 2021-11-18  2996.770020
# 2021-11-19  2978.530029
# 2021-11-22  2926.040039
# 2021-11-23  2915.639893
# 2021-11-24  2922.399902
#
# [1738 rows x 6 columns]

# %% [markdown]
# Calculo la variación del previo de la acción vs el día anterior.

# %%
df['price_ratio']=df['Adj Close']/df['Adj Close'].shift(1)

# %%
df['price_ratio'].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.loc[df['price_ratio'].isna(),'price_ratio']=1
df['cum_price']=df['price_ratio'].cumprod()

# %%
df
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2015-01-02   535.799988   527.880005   532.599976   529.549988  1324000
# 2015-01-05   527.989990   517.750000   527.150024   519.460022  2059100
# 2015-01-06   521.210022   505.549988   520.500000   506.640015  2722800
# 2015-01-07   511.489990   503.649994   510.950012   505.149994  2345900
# 2015-01-08   507.500000   495.019989   501.510010   506.910004  3652700
# ...                 ...          ...          ...          ...      ...
# 2021-11-18  3011.610107  2957.689941  2964.830078  2996.770020  1780400
# 2021-11-19  3019.330078  2977.979980  2999.510010  2978.530029  1684100
# 2021-11-22  2996.590088  2922.949951  2986.649902  2926.040039  1529700
# 2021-11-23  2933.199951  2882.300049  2923.060059  2915.639893  1360900
# 2021-11-24  2924.989990  2887.459961  2909.469971  2922.399902   900900
#
#               Adj Close  price_ratio  cum_price
# Date
# 2015-01-02   529.549988     1.000000   1.000000
# 2015-01-05   519.460022     0.980946   0.980946
# 2015-01-06   506.640015     0.975321   0.956737
# 2015-01-07   505.149994     0.997059   0.953923
# 2015-01-08   506.910004     1.003484   0.957247
# ...                 ...          ...        ...
# 2021-11-18  2996.770020     1.012101   5.659088
# 2021-11-19  2978.530029     0.993913   5.624644
# 2021-11-22  2926.040039     0.982377   5.525522
# 2021-11-23  2915.639893     0.996446   5.505882
# 2021-11-24  2922.399902     1.002319   5.518648
#
# [1738 rows x 8 columns]

# %%
df['cum_price'].plot(figsize=(16,8));
df['cum_price'][[0,-1]]
# Out:
# Date
# 2015-01-02    1.000000
# 2021-11-24    5.518648
# Name: cum_price, dtype: float64

# %% [markdown]
# Ahora voy a calcular las variaciones de precio de los 5 días anteriores para introducirlas en un modelo y el volumen de los 5 días anteriores

# %%
df['price_ratio1']=df['price_ratio'].shift(1)
df['price_ratio2']=df['price_ratio'].shift(2)
df['price_ratio3']=df['price_ratio'].shift(3)
df['price_ratio4']=df['price_ratio'].shift(4)
df['price_ratio5']=df['price_ratio'].shift(5)
df['price_ratio6']=df['price_ratio'].shift(6)
df['price_ratio7']=df['price_ratio'].shift(7)

# %%
df.head(10)
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2015-01-02  535.799988  527.880005  532.599976  529.549988  1324000
# 2015-01-05  527.989990  517.750000  527.150024  519.460022  2059100
# 2015-01-06  521.210022  505.549988  520.500000  506.640015  2722800
# 2015-01-07  511.489990  503.649994  510.950012  505.149994  2345900
# 2015-01-08  507.500000  495.019989  501.510010  506.910004  3652700
# 2015-01-09  508.600006  498.649994  508.179993  500.720001  2100000
# 2015-01-12  500.279999  490.910004  499.239990  497.059998  2856900
# 2015-01-13  508.600006  497.260010  502.570007  501.799988  3047900
# 2015-01-14  508.260010  498.160004  500.420013  505.929993  2640000
# 2015-01-15  509.750000  502.010010  508.890015  504.010010  2553400
#
#              Adj Close  price_ratio  cum_price  price_ratio1  price_ratio2  \
# Date
# 2015-01-02  529.549988     1.000000   1.000000           NaN           NaN
# 2015-01-05  519.460022     0.980946   0.980946      1.000000           NaN
# 2015-01-06  506.640015     0.975321   0.956737      0.980946      1.000000
# 2015-01-07  505.149994     0.997059   0.953923      0.975321      0.980946
# 2015-01-08  506.910004     1.003484   0.957247      0.997059      0.975321
# 2015-01-09  500.720001     0.987789   0.945558      1.003484      0.997059
# 2015-01-12  497.059998     0.992691   0.938646      0.987789      1.003484
# 2015-01-13  501.799988     1.009536   0.947597      0.992691      0.987789
# 2015-01-14  505.929993     1.008230   0.955396      1.009536      0.992691
# 2015-01-15  504.010010     0.996205   0.951770      1.008230      1.009536
#
#             price_ratio3  price_ratio4  price_ratio5  price_ratio6  \
# Date
# 2015-01-02           NaN           NaN           NaN           NaN
# 2015-01-05           NaN           NaN           NaN           NaN
# 2015-01-06           NaN           NaN           NaN           NaN
# 2015-01-07      1.000000           NaN           NaN           NaN
# 2015-01-08      0.980946      1.000000           NaN           NaN
# 2015-01-09      0.975321      0.980946      1.000000           NaN
# 2015-01-12      0.997059      0.975321      0.980946      1.000000
# 2015-01-13      1.003484      0.997059      0.975321      0.980946
# 2015-01-14      0.987789      1.003484      0.997059      0.975321
# 2015-01-15      0.992691      0.987789      1.003484      0.997059
#
#             price_ratio7
# Date
# 2015-01-02           NaN
# 2015-01-05           NaN
# 2015-01-06           NaN
# 2015-01-07           NaN
# 2015-01-08           NaN
# 2015-01-09           NaN
# 2015-01-12           NaN
# 2015-01-13      1.000000
# 2015-01-14      0.980946
# 2015-01-15      0.975321

# %%
# Borramos todos los registros que tengan algún valor NaN
df.dropna(inplace=True)

# %%
# 0: Vender
# 1: Mantener
# 2: Comprar

df['comprar']=[0 if (x-1)<-0.0075 else 2 if (x-1)>0.0075 else 1 for x in df['price_ratio']]

# %%
df.head(10)
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2015-01-13  508.600006  497.260010  502.570007  501.799988  3047900
# 2015-01-14  508.260010  498.160004  500.420013  505.929993  2640000
# 2015-01-15  509.750000  502.010010  508.890015  504.010010  2553400
# 2015-01-16  510.850006  503.089996  503.149994  510.459991  2482900
# 2015-01-20  515.609985  509.369995  512.770020  509.940002  2339800
# 2015-01-21  521.849976  509.589996  510.839996  520.390015  2317800
# 2015-01-22  538.840027  521.909973  523.000000  537.299988  2803400
# 2015-01-23  545.409973  535.750000  538.030029  541.950012  2298300
# 2015-01-26  541.500000  532.070007  541.500000  536.719971  1546600
# 2015-01-27  532.780029  520.859985  531.400024  521.190002  1957400
#
#              Adj Close  price_ratio  cum_price  price_ratio1  price_ratio2  \
# Date
# 2015-01-13  501.799988     1.009536   0.947597      0.992691      0.987789
# 2015-01-14  505.929993     1.008230   0.955396      1.009536      0.992691
# 2015-01-15  504.010010     0.996205   0.951770      1.008230      1.009536
# 2015-01-16  510.459991     1.012797   0.963951      0.996205      1.008230
# 2015-01-20  509.940002     0.998981   0.962969      1.012797      0.996205
# 2015-01-21  520.390015     1.020493   0.982702      0.998981      1.012797
# 2015-01-22  537.299988     1.032495   1.014635      1.020493      0.998981
# 2015-01-23  541.950012     1.008654   1.023416      1.032495      1.020493
# 2015-01-26  536.719971     0.990350   1.013540      1.008654      1.032495
# 2015-01-27  521.190002     0.971065   0.984213      0.990350      1.008654
#
#             price_ratio3  price_ratio4  price_ratio5  price_ratio6  \
# Date
# 2015-01-13      1.003484      0.997059      0.975321      0.980946
# 2015-01-14      0.987789      1.003484      0.997059      0.975321
# 2015-01-15      0.992691      0.987789      1.003484      0.997059
# 2015-01-16      1.009536      0.992691      0.987789      1.003484
# 2015-01-20      1.008230      1.009536      0.992691      0.987789
# 2015-01-21      0.996205      1.008230      1.009536      0.992691
# 2015-01-22      1.012797      0.996205      1.008230      1.009536
# 2015-01-23      0.998981      1.012797      0.996205      1.008230
# 2015-01-26      1.020493      0.998981      1.012797      0.996205
# 2015-01-27      1.032495      1.020493      0.998981      1.012797
#
#             price_ratio7  comprar
# Date
# 2015-01-13      1.000000        2
# 2015-01-14      0.980946        2
# 2015-01-15      0.975321        1
# 2015-01-16      0.997059        2
# 2015-01-20      1.003484        1
# 2015-01-21      0.987789        2
# 2015-01-22      0.992691        2
# 2015-01-23      1.009536        2
# 2015-01-26      1.008230        0
# 2015-01-27      0.996205        0

# %%
variables_X=['price_ratio1',
              'price_ratio2',
              'price_ratio3',
              'price_ratio4',
              'price_ratio5',
              'price_ratio6',
              'price_ratio7']
df_X=df[variables_X]
df_y=df['comprar']

# %%
scaled_features = {}
for each in variables_X:
    mean, std = df_X[each].mean(), df_X[each].std()
    scaled_features[each] = [mean, std]
    df_X.loc[:, each] = (df_X[each] - mean)/std
# Out:
# C:\Users\Usuario\.conda\envs\finance\lib\site-packages\pandas\core\indexing.py:1781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
scaled_features
# Out:
# {'price_ratio1': [1.0011570637000249, 0.01669946092152764],
#  'price_ratio2': [1.001152062600337, 0.016702168744335083],
#  'price_ratio3': [1.0011642560819263, 0.016696157684333635],
#  'price_ratio4': [1.001166073277048, 0.016695539225615345],
#  'price_ratio5': [1.0011448252115365, 0.016705016773517045],
#  'price_ratio6': [1.0011331497653027, 0.016712069867549948],
#  'price_ratio7': [1.0011353912722705, 0.016711657284210577]}

# %%
df_X
# Out:
#             price_ratio1  price_ratio2  price_ratio3  price_ratio4  \
# Date
# 2015-01-13     -0.506995     -0.800094      0.138947     -0.245997
# 2015-01-14      0.501752     -0.506614     -0.801113      0.138843
# 2015-01-15      0.423566      0.501970     -0.507526     -0.801251
# 2015-01-16     -0.296538      0.423796      0.501421     -0.507654
# 2015-01-20      0.697044     -0.296190      0.423219      0.501330
# ...                  ...           ...           ...           ...
# 2021-11-18     -0.000043     -0.301285     -0.160775      1.126507
# 2021-11-19      0.655342      0.000257     -0.302124     -0.160890
# 2021-11-22     -0.433763      0.655535     -0.000474     -0.302244
# 2021-11-23     -1.124578     -0.433394      0.655040     -0.000583
# 2021-11-24     -0.282129     -1.124096     -0.434280      0.654956
#
#             price_ratio5  price_ratio6  price_ratio7
# Date
# 2015-01-13     -1.545902     -1.207929     -0.067940
# 2015-01-14     -0.244586     -1.544551     -1.208093
# 2015-01-15      0.140036     -0.243784     -1.544723
# 2015-01-16     -0.799525      0.140676     -0.243924
# 2015-01-20     -0.506094     -0.798488      0.140545
# ...                  ...           ...           ...
# 2021-11-18     -0.120643     -1.283280     -0.113111
# 2021-11-19      1.127140     -0.119893     -1.283446
# 2021-11-22     -0.159527      1.127363     -0.120030
# 2021-11-23     -0.300800     -0.158761      1.127257
# 2021-11-24      0.000690     -0.299975     -0.158899
#
# [1731 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)
# %matplotlib inline
plt.figure(figsize=(15, 10))
sns.heatmap(df_X.corr(),annot=True);

# %%
sns.pairplot(df_X)

# %%
df_y.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
X_train=df_X[:-60]
X_test=df_X[-60:]
y_train=df_y[:-60]
y_test=df_y[-60:]

# %%
X_train
# Out:
#             price_ratio1  price_ratio2  price_ratio3  price_ratio4  \
# Date
# 2015-01-13     -0.506995     -0.800094      0.138947     -0.245997
# 2015-01-14      0.501752     -0.506614     -0.801113      0.138843
# 2015-01-15      0.423566      0.501970     -0.507526     -0.801251
# 2015-01-16     -0.296538      0.423796      0.501421     -0.507654
# 2015-01-20      0.697044     -0.296190      0.423219      0.501330
# ...                  ...           ...           ...           ...
# 2021-08-25      0.452386      1.068965      0.702560      0.032309
# 2021-08-26      0.277261      0.452612      1.068620      0.702477
# 2021-08-27     -0.338397      0.277516      0.452045      1.068551
# 2021-08-30      1.016031     -0.338043      0.276885      0.451953
# 2021-08-31      0.174600      1.016166     -0.338895      0.276787
#
#             price_ratio5  price_ratio6  price_ratio7
# Date
# 2015-01-13     -1.545902     -1.207929     -0.067940
# 2015-01-14     -0.244586     -1.544551     -1.208093
# 2015-01-15      0.140036     -0.243784     -1.544723
# 2015-01-16     -0.799525      0.140676     -0.243924
# 2015-01-20     -0.506094     -0.798488      0.140545
# ...                  ...           ...           ...
# 2021-08-25     -0.599647     -0.780780      0.184919
# 2021-08-26      0.033562     -0.598695     -0.780933
# 2021-08-27      0.703350      0.034247     -0.598844
# 2021-08-30      1.069216      0.703752      0.034113
# 2021-08-31      0.452968      1.069464      0.703635
#
# [1671 rows x 7 columns]

# %%
y_test.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
y_train.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=18, 
                                activation='sigmoid', 
                                input_shape=(df_X.shape[1], )))


model.add(tf.keras.layers.Dense(units=3, 
                                activation='softmax',
                                batch_size=16))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.005)
model.compile(optimizer=optimizer, 
              loss='sparse_categorical_crossentropy', 
              metrics=['sparse_categorical_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 18)                144
#
#  dense_7 (Dense)             (None, 3)                 57
#
# =================================================================
# Total params: 201
# Trainable params: 201
# Non-trainable params: 0
# _________________________________________________________________

# %%
NUM_EPOCHS=250
history=model.fit(X_train, y_train,
                  epochs=NUM_EPOCHS,
                  callbacks=[TqdmCallback()], # coloca una barra de progreso
                  validation_split=0.15,
                  verbose=0)
# Out:
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 993us/step - loss: 1.1435 - sparse_categorical_accuracy: 0.4000

# %%
def plotCurves(history,epochs):

    plt.plot(history.history['sparse_categorical_accuracy'],'r')
    plt.plot(history.history['val_sparse_categorical_accuracy'],'g')
    plt.xticks(np.arange(0, epochs, 50.0))
    plt.rcParams['figure.figsize'] = (8, 6)
    plt.xlabel("Num of Epochs")
    plt.ylabel("categorical_accuracy")
    plt.title("Training vs Validation Sparse Categorical Accuracy")
    plt.legend(['train','validation'])
 
    plt.show()

# %%
plotCurves(history,NUM_EPOCHS)

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
labels = [0,1,2]
cm=confusion_matrix(y_test.values,
                    predictions.argmax(axis=1))
cm
# Out:
# array([[ 0, 11,  3],
#        [ 2, 16, 10],
#        [ 1,  9,  8]], dtype=int64)

# %%
sns.heatmap(cm,
            annot=True,
            fmt='d',
            cmap='Greens')
plt.ylabel('Actual')
plt.xlabel('Predicted');

# %% [markdown]
# ### Recall o true positive rate (TPR)
#
# Porcentaje de casos positivos correctamente clasificados
# $$TPR=\frac{TP}{TP+FN}$$
#
# ### Precision (PPV)
#
# Porcentaje de realmente correctos a partir de los casos clasificados como correctos
# $$PPV=\frac{TP}{TP+FP}$$
#
# ### Accuracy (ACC)
#
# Porcentaje de predicciones correctas
# $$ACC=\frac{TP+TN}{TP+TN+FP+FN}$$
#
# ### F-measure
# Media armonica de TPR y PPV.
#
# $$Fmeasure=\frac{2 \times TPR \times PPV}{TPR+PPV}$$

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score 
print(accuracy_score(y_test.values,
                    predictions.argmax(axis=1)))
print(classification_report(y_test.values,
                    predictions.argmax(axis=1)))
# Out:
# 0.4
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        14
#            1       0.44      0.57      0.50        28
#            2       0.38      0.44      0.41        18
#
#     accuracy                           0.40        60
#    macro avg       0.28      0.34      0.30        60
# weighted avg       0.32      0.40      0.36        60

# %% [markdown]
# Dibujamos la posición que el modelo nos ha dado como resultado

# %%
# Convierto la serie en un dataframe
df_y=y_test.to_frame()
# Cambio el nombre de la variable a optima
df_y.rename({'comprar':'optima'}, axis=1,inplace=True)  # new method
# Cambio los valores de la columna real a 0 mantener, 1 comprar, -1 vender
df_y['optima']= [0 if x==1 else 1 if x==2 else -1 for x in df_y['optima']]
# inserto en el DataFrame mis previsiones
df_y['prevision']=predictions.argmax(axis=1)
# Cambio los valores de la columna prevision a 0 mantener, 1 comprar, -1 vender
df_y['prevision']= [0 if x==1 else 1 if x==2 else -1 for x in df_y['prevision']]
# Dibujo las posiciones a lo largo del tiempo
df_y.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# copio las variaciones diarias del historico
df_y['returns']=df['price_ratio']
# calculo la rentabilidad obtenida de solo mantener
df_y['cum_returns']=df_y['returns'].cumprod()

# %%
# calculo la rentabilidad del modelo
df_y['model_returns']=df_y['returns']*df_y['prevision']
df_y.loc[df_y['prevision'] ==-1, 'model_returns'] = df_y['model_returns']+2

# %%
# copio las variaciones diarias del historico
df_y['returns']=df['price_ratio']
# calculo la rentabilidad obtenida de solo mantener
df_y['cum_returns']=df_y['returns'].cumprod()
# calculo la rentabilidad del modelo
df_y['model_returns']=df_y['returns']*df_y['prevision']
df_y.loc[df_y['prevision'] ==-1, 'model_returns'] = df_y['model_returns']+2
df_y.loc[df_y['prevision'] ==0, 'model_returns'] = 1

# calculo la rentabilidad acumulada del modelo
df_y['cum_model_returns']=df_y['model_returns'].cumprod()
# calulo la rentabilidad acululada óptima
df_y['optima_returns']=df_y['returns']*df_y['optima']
df_y.loc[df_y['optima'] ==-1, 'optima_returns'] = df_y['optima_returns']+2
df_y.loc[df_y['optima'] ==0, 'optima_returns'] = 1

df_y['cum_optima_returns']=df_y['optima_returns'].cumprod()
df_y.head()
# Out:
#             optima  prevision   returns  cum_returns  model_returns  \
# Date
# 2021-09-01       0          0  1.003580     1.003580       1.000000
# 2021-09-02      -1          0  0.986720     0.990252       1.000000
# 2021-09-03       0          0  1.003158     0.993379       1.000000
# 2021-09-07       0          0  1.003764     0.997118       1.000000
# 2021-09-08       0          1  0.995914     0.993044       0.995914
#
#             cum_model_returns  optima_returns  cum_optima_returns
# Date
# 2021-09-01           1.000000         1.00000             1.00000
# 2021-09-02           1.000000         1.01328             1.01328
# 2021-09-03           1.000000         1.00000             1.01328
# 2021-09-07           1.000000         1.00000             1.01328
# 2021-09-08           0.995914         1.00000             1.01328

# %%
df_y[['cum_returns','cum_model_returns']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
costes_transaccion=0.002
df_y['costes_transaccion']=np.abs(costes_transaccion*df_y['prevision'])
df_y['model_returns_ct']=df_y['model_returns']*(1-df_y['costes_transaccion'])
df_y['cum_model_returns_ct']=df_y['model_returns_ct'].cumprod()
print('Costes Transacción '+str(costes_transaccion*100)+"%")
print(df_y[['cum_returns','cum_model_returns','cum_model_returns_ct']][-1:])
chart_title='Análisis Simulación Modelo. Compañía:'+stock
df_y[['cum_returns','cum_model_returns','cum_model_returns_ct']].plot(title=chart_title);
# Out:
# Costes Transacción 0.2%
#             cum_returns  cum_model_returns  cum_model_returns_ct
# Date
# 2021-11-24     1.009831           1.078559              1.027962

# %%
df_y[['prevision','optima']].plot(kind='hist',subplots=True)
