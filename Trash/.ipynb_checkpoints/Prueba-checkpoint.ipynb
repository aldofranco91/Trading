# %%
# %reset -f

# %%
import pandas as pd
import numpy as np
import pandas_datareader as pdr

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

from datetime import date, timedelta

from binance.client import Client

# %%
api_key = "bKln6gBUJO0cJRwnZakqNpHfmcKR5TmiqMmrkvVWgM1k0H0ZEli0mmNARIYb2b9C"
api_secret = "4dbva7d575El2ehXaqI95tZtrFvBVoG0NFPXVXlY1xikec5VgLzYWFeHNZvnEL4Y"

# %%
client = Client(api_key, api_secret)

# %%
cota_inferior = str(date.today() - timedelta(500))
print("Cota Inferior de fecha: " + cota_inferior)
# Out:
# Cota Inferior de fecha: 2019-12-18

# %%
index = 'BTCUSDT'

# %%
# valid intervals - 1m, 3m, 5m, 15m, 30m, 1h, 2h, 4h, 6h, 8h, 12h, 1d, 3d, 1w, 1M

bars = client.get_historical_klines(index, '1d', cota_inferior)

columnas = ['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time',
           'quote_asset_volume','number_of_trades','taker_buy_base_asset_volume',
           'taker_buy_quote_asset_volume','ignore']

# %%
df = pd.DataFrame(bars, columns = columnas, dtype='float')

df["open_time"] = pd.to_datetime(df["open_time"], unit='ms')

df.index = df["open_time"]

df.drop(columns=["close_time","ignore","open_time",
                 #"quote_asset_volume","taker_buy_base_asset_volume","taker_buy_quote_asset_volume"
                ], inplace = True)

df.drop(df.tail(1).index,inplace=True) # drop last n rows quitamos el día actual

print("Shape: " + str(df.shape))

pd.concat([df.head(3), df.tail(3)])
# Out:
# Shape: (500, 9)
#                 open      high       low     close        volume  \
# open_time
# 2019-12-18   6623.84   7440.00   6435.00   7277.83  95636.651251
# 2019-12-19   7277.83   7380.00   7038.31   7150.30  55509.049075
# 2019-12-20   7151.31   7220.00   7079.50   7187.83  32132.069205
# 2021-04-28  55011.97  56428.00  53813.16  54846.22  55130.459015
# 2021-04-29  54846.23  55195.84  52330.94  53555.00  52486.019455
# 2021-04-30  53555.00  57963.00  53013.01  57694.27  68578.910045
#
#             quote_asset_volume  number_of_trades  taker_buy_base_asset_volume  \
# open_time
# 2019-12-18        6.540572e+08          714073.0                 49843.650817
# 2019-12-19        3.974077e+08          439761.0                 27456.528272
# 2019-12-20        2.298427e+08          312766.0                 16641.052689
# 2021-04-28        3.020243e+09         1830042.0                 26762.033422
# 2021-04-29        2.823220e+09         1763676.0                 25339.743902
# ...

# %%
def description(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Missing'] = df.isnull().sum().values
    summary['PercMissing'] = df.isnull().sum().values / df.isnull().count().values
    summary['Uniques'] = df.nunique().values
    return summary

description(df)
# Out:
# Dataset Shape: (500, 9)
#                           index   dtypes  Missing  PercMissing  Uniques
# 0                          open  float64        0          0.0      500
# 1                          high  float64        0          0.0      493
# 2                           low  float64        0          0.0      494
# 3                         close  float64        0          0.0      500
# 4                        volume  float64        0          0.0      500
# 5            quote_asset_volume  float64        0          0.0      500
# 6              number_of_trades  float64        0          0.0      500
# 7   taker_buy_base_asset_volume  float64        0          0.0      500
# 8  taker_buy_quote_asset_volume  float64        0          0.0      500

# %%
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot

plt.figure(figsize=(15,6))

# Creating Autocorrelation plot
for variable in df.columns:
    print("Variable: " + str(variable))
    ax = autocorrelation_plot(df[variable],)
# Out:
# Variable: open
# Variable: high
# Variable: low
# Variable: close
# Variable: volume
# Variable: quote_asset_volume
# Variable: number_of_trades
# Variable: taker_buy_base_asset_volume
# Variable: taker_buy_quote_asset_volume

# %%
# Get feature from dates
# df['year'] = df.index.year
#df['month'] = df.index.month
df['day'] = df.index.day
df['weekday'] = df.index.dayofweek
#df['dayofyear'] = df.index.dayofyear
#df['is_month_start'] = (df.index.is_month_start).astype(int)
#df['is_month_end'] = (df.index.is_month_end).astype(int)

# %%
df.sample()
# Out:
#                open    high      low    close        volume  \
# open_time
# 2020-06-30  9192.93  9205.0  9064.89  9138.55  31463.162801
#
#             quote_asset_volume  number_of_trades  taker_buy_base_asset_volume  \
# open_time
# 2020-06-30        2.877813e+08          328083.0                 15267.747467
#
#             taker_buy_quote_asset_volume  day  weekday
# open_time
# 2020-06-30                  1.396747e+08   30        1

# %%
df.head()
# Out:
#                open     high      low    close        volume  \
# open_time
# 2019-12-18  6623.84  7440.00  6435.00  7277.83  95636.651251
# 2019-12-19  7277.83  7380.00  7038.31  7150.30  55509.049075
# 2019-12-20  7151.31  7220.00  7079.50  7187.83  32132.069205
# 2019-12-21  7188.01  7190.58  7105.00  7132.75  19467.174028
# 2019-12-22  7131.59  7518.54  7122.47  7501.44  39137.455150
#
#             quote_asset_volume  number_of_trades  taker_buy_base_asset_volume  \
# open_time
# 2019-12-18        6.540572e+08          714073.0                 49843.650817
# 2019-12-19        3.974077e+08          439761.0                 27456.528272
# 2019-12-20        2.298427e+08          312766.0                 16641.052689
# 2019-12-21        1.390692e+08          212162.0                 10119.761012
# 2019-12-22        2.855772e+08          356612.0                 20625.436732
#
#             taker_buy_quote_asset_volume  day  weekday
# open_time
# ...

# %%
#https://towardsdatascience.com/building-a-comprehensive-set-of-technical-indicators-in-python-for-quantitative-trading-8d98751b5fb
# MovingAverage
values_ma = [5,15,30]

for i in values_ma:
    df["ma_close_" + str(i)] = df["close"].rolling(window=i).mean()
    df["ma_volume_" + str(i)] = df["volume"].rolling(window=i).mean()

# ExponentialMovingWindow
values_ema = [5,15,30]

for i in values_ema:
    df["ema_" + str(i)] = df["close"].ewm(span = i, adjust = False).mean()
    
# RSI https://stackoverflow.com/questions/20526414/relative-strength-index-in-python-pandas
values_rsi = [7,14,21]
close = df['close']

# Get the difference in price from previous step
delta = close.diff()

# Make the positive gains (up) and negative gains (down) Series
up, down = delta.copy(), delta.copy()
up[up < 0] = 0
down[down > 0] = 0

for i in values_rsi:
    # Calculate the EWMA
    roll_up1 = up.ewm(span=i).mean()
    roll_down1 = down.abs().ewm(span=i).mean()

    # Calculate the RSI based on EWMA
    RS1 = roll_up1 / roll_down1
    RSI1 = 100.0 - (100.0 / (1.0 + RS1))

    # Calculate the SMA
    roll_up2 = up.rolling(i).mean()
    roll_down2 = down.abs().rolling(i).mean()

    # Calculate the RSI based on SMA
    RS2 = roll_up2 / roll_down2
    RSI2 = 100.0 - (100.0 / (1.0 + RS2))
    
    df["rsi_ewma_" + str(i)] = RSI1.values
    df["rsi_sma_" + str(i)]  = RSI2.values
    
# BollingerBand
values_bollinger = [5,10,20]
for i in values_bollinger:
    df['bollinger_upper_' + str(i)] = df['close'].rolling(window=i).mean() + (df['close'].rolling(window=i).std()  * 2)
    df['bollinger_lower_' + str(i)] = df['close'].rolling(window=i).mean() - (df['close'].rolling(window=i).std()  * 2)

# Rate of change
values_rc = [5,15,30]
for i in values_rc:
    df["rc_" + str(i)] = df["close"].pct_change(periods = i)
    
# Stochastic Oscillators
values_so = [5,15,30]
for i in values_so:
    lowest = df["low"].rolling(window = i).min()
    high = df["high"].rolling(window = i).max()
    df["so_" + str(i)] = ((df['close'] -lowest)/(high - lowest))*100
    df["so_%D" + str(i)] = df["so_" + str(i)].rolling(window = i).mean()

# %%
#df["y_high"] = df["high"].shift(-1)
#df["y_low"] = df["low"].shift(-1)
#df[["y_high","high","y_low","low"]].tail()

df["y_close"] = df["close"].shift(-1)
df[["y_close","close"]].tail()
# Out:
#              y_close     close
# open_time
# 2021-04-26  55011.97  54001.39
# 2021-04-27  54846.22  55011.97
# 2021-04-28  53555.00  54846.22
# 2021-04-29  57694.27  53555.00
# 2021-04-30       NaN  57694.27

# %%
past_t = 15 # Es hiperparametro del modelo
minus = 3

# %%
list_shift = list(range(1, minus))

for i in list_shift: 
    #df["close_minus" + str(i)] = df["close"].shift(i)
    df["high_minus" + str(i)] = df["high"].shift(i)
    df["low_minus" + str(i)] = df["low"].shift(i)
    #df["open_minus" + str(i)] = df["open"].shift(i)
    df["volume_minus" + str(i)] = df["volume"].shift(i)
    df["number_of_trades" + str(i)] = df["number_of_trades"].shift(i)

# %%
df.head()
# Out:
#                open     high      low    close        volume  \
# open_time
# 2019-12-18  6623.84  7440.00  6435.00  7277.83  95636.651251
# 2019-12-19  7277.83  7380.00  7038.31  7150.30  55509.049075
# 2019-12-20  7151.31  7220.00  7079.50  7187.83  32132.069205
# 2019-12-21  7188.01  7190.58  7105.00  7132.75  19467.174028
# 2019-12-22  7131.59  7518.54  7122.47  7501.44  39137.455150
#
#             quote_asset_volume  number_of_trades  taker_buy_base_asset_volume  \
# open_time
# 2019-12-18        6.540572e+08          714073.0                 49843.650817
# 2019-12-19        3.974077e+08          439761.0                 27456.528272
# 2019-12-20        2.298427e+08          312766.0                 16641.052689
# 2019-12-21        1.390692e+08          212162.0                 10119.761012
# 2019-12-22        2.855772e+08          356612.0                 20625.436732
#
#             taker_buy_quote_asset_volume  day  weekday  ma_close_5  \
# open_time
# ...

# %%
print("Shape: " + str(df.shape))
df.dropna(inplace = True)
print("Shape: " + str(df.shape))
# Out:
# Shape: (500, 50)
# Shape: (441, 50)

# %%
X = df.drop(columns=["y_low","y_high"]).copy()
y_low = df["y_low"].copy()
y_high = df["y_high"].copy()

# %%
from catboost import CatBoostRegressor

modelo = CatBoostRegressor(loss_function='MAE', # Funcion minimizadora del modelo https://catboost.ai/docs/concepts/loss-functions-regression.html
                           verbose = 0,
                           task_type = "CPU" #GPU
                          )

parameters = {'depth' : [2,4,6],
              'learning_rate' : [0.01, 0.1],
              'iterations' : [1000, 2000] }

from sklearn.model_selection import GridSearchCV

grid_catboost = GridSearchCV(estimator = modelo,
                             param_grid = parameters,
                             scoring = "max_error", # https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter
                             #return_train_score = True,
                             cv = 5,
                             n_jobs = -1,
                             verbose = 0              
                            )

# %%
y_real_low = pd.DataFrame(list(y_low.iloc[past_t:len(y_low)]), columns = ["y_real_low"], index = y_low.iloc[past_t:len(y_low)].index)
y_pred_low = pd.DataFrame([999] * (len(y_low)-past_t), columns = ["y_pred_low"], index = y_low.iloc[past_t:len(y_low)].index)

comparacion_low = pd.concat([y_real_low, y_pred_low], axis =1).copy()

y_real_high = pd.DataFrame(list(y_high.iloc[past_t:len(y_high)]), columns = ["y_real_high"], index = y_high.iloc[past_t:len(y_high)].index)
y_pred_high = pd.DataFrame([999] * (len(y_high)-past_t), columns = ["y_pred_high"], index = y_high.iloc[past_t:len(y_high)].index)

comparacion_high = pd.concat([y_real_high, y_pred_high], axis =1).copy()

# %%
X.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume', 'quote_asset_volume',
#        'number_of_trades', 'taker_buy_base_asset_volume',
#        'taker_buy_quote_asset_volume', 'day', 'weekday', 'ma_close_5',
#        'ma_volume_5', 'ma_close_15', 'ma_volume_15', 'ma_close_30',
#        'ma_volume_30', 'ema_5', 'ema_15', 'ema_30', 'rsi_ewma_7', 'rsi_sma_7',
#        'rsi_ewma_14', 'rsi_sma_14', 'rsi_ewma_21', 'rsi_sma_21',
#        'bollinger_upper_5', 'bollinger_lower_5', 'bollinger_upper_10',
#        'bollinger_lower_10', 'bollinger_upper_20', 'bollinger_lower_20',
#        'rc_5', 'rc_15', 'rc_30', 'so_5', 'so_%D5', 'so_15', 'so_%D15', 'so_30',
#        'so_%D30', 'high_minus1', 'low_minus1', 'volume_minus1',
#        'number_of_trades1', 'high_minus2', 'low_minus2', 'volume_minus2',
#        'number_of_trades2', 'high_minus3', 'low_minus3', 'volume_minus3',
#        'number_of_trades3', 'high_minus4', 'low_minus4', 'volume_minus4',
#        'number_of_trades4'],
# ...

# %%
tope = len(df)-past_t
df_imp_low = []
df_imp_high = []
for i in range(0, tope):
    # Train
    X_train = X.iloc[i:i+past_t]
    y_train_low = y_low.iloc[i:i+past_t]
    y_train_high = y_high.iloc[i:i+past_t]
    # Test
    X_test = X.iloc[i+past_t]
    y_test_low = y_low.iloc[i+past_t]
    y_test_high = y_high.iloc[i+past_t]
    
    # Train Low
    grid_catboost.fit(X_train, y_train_low)
    pred = grid_catboost.best_estimator_.predict(X_test)
    comparacion_low.at[ y_low.iloc[past_t:len(y_low)].index[i] , 'y_pred_low'] = pred
    fea_imp = pd.DataFrame({'imp': grid_catboost.best_estimator_.feature_importances_, 'col': X_train.columns})
    df_imp_low.append(fea_imp)
    print("Iteration LOW: " + str(i+1) + "/" + str(tope) + " | Date " + str(X_test.name) + " | RealValue " + str(y_test_low) + " | Prediccion " + str(pred), end='\r')
    
    # Train High
    grid_catboost.fit(X_train, y_train_high)
    pred = grid_catboost.best_estimator_.predict(X_test)
    comparacion_high.at[ y_high.iloc[past_t:len(y_high)].index[i] , 'y_pred_high'] = pred
    fea_imp = pd.DataFrame({'imp': grid_catboost.best_estimator_.feature_importances_, 'col': X_train.columns})
    df_imp_high.append(fea_imp)
    print("Iteration HIGH: " + str(i+1) + "/" + str(tope) + " | Date " + str(X_test.name) + " | RealValue " + str(y_test_high) + " | Prediccion " + str(pred), end='\r')
# Out:
# Iteration HIGH: 410/410 | Date 2021-04-27 00:00:00 | RealValue 56428.0 | Prediccion 56887.7144809222454

# %%
# Variables TOP Low
fea_imp = pd.concat(df_imp_low)
print(fea_imp.shape)
fea_imp = fea_imp.groupby(["col"], as_index =  False).agg({"imp" : 'mean'})
print(fea_imp.shape)
fea_imp = fea_imp.sort_values(['imp', 'col'], ascending=[True, False])#.iloc[-20:]
_ = fea_imp.plot(kind='barh', x='col', y='imp', figsize=(20, 20))
# Out:
# (23370, 2)
# (57, 2)

# %%
# Variables TOP High
fea_imp = pd.concat(df_imp_high)
print(fea_imp.shape)
fea_imp = fea_imp.groupby(["col"], as_index =  False).agg({"imp" : 'mean'})
print(fea_imp.shape)
fea_imp = fea_imp.sort_values(['imp', 'col'], ascending=[True, False])#.iloc[-20:]
_ = fea_imp.plot(kind='barh', x='col', y='imp', figsize=(20, 20))
# Out:
# (23370, 2)
# (57, 2)

# %%
comparacion_low["y_pred_low"].describe()
# Out:
# count      410.000000
# mean     20760.826829
# std      16498.014001
# min       4701.000000
# 25%       9176.500000
# 50%      11352.500000
# 75%      31520.500000
# max      60494.000000
# Name: y_pred_low, dtype: float64

# %%
comparacion_high["y_pred_high"].describe()
# Out:
# count      410.000000
# mean     22310.460976
# std      17947.547499
# min       5838.000000
# 25%       9541.500000
# 50%      11776.500000
# 75%      35262.000000
# max      63393.000000
# Name: y_pred_high, dtype: float64

# %%
plt.figure(figsize=(20, 6))
plt.title("Real vs Prediccion LOW")
plt.plot(comparacion_low["y_pred_low"], color = "blue", label="Pred") # markers mete un *
plt.plot(comparacion_low["y_real_low"], color = 'red', label="Real")
plt.ylabel('Value'); plt.xlabel('Time Step'); plt.legend(fontsize=11)

# %%
plt.figure(figsize=(20, 6))
plt.title("Real vs Prediccion HIGH")
plt.plot(comparacion_high["y_pred_high"], color = "blue", label="Pred") # markers mete un *
plt.plot(comparacion_high["y_real_high"], color = 'red', label="Real")
plt.ylabel('Value'); plt.xlabel('Time Step'); plt.legend(fontsize=11)

# %%
from sklearn.metrics import mean_absolute_percentage_error
print("MAPE LOW : " + str(mean_absolute_percentage_error(y_pred = comparacion_low["y_pred_low"], y_true = comparacion_low["y_real_low"]) * 100)) # Viene sin multiplcar por 100
print("MAPE HIGH: " + str(mean_absolute_percentage_error(y_pred = comparacion_high["y_pred_high"], y_true = comparacion_high["y_real_high"]) * 100)) # Viene sin multiplcar por 100
# Out:
# MAPE LOW : 3.640521243658521
# MAPE HIGH: 3.013370746452486

# %%
errores_low = abs(comparacion_low["y_pred_low"] - comparacion_low["y_real_low"])
errores_high = abs(comparacion_high["y_pred_high"] - comparacion_high["y_real_high"])

best_pred_low = np.argmin(errores_low)
worse_pred_low = np.argmax(errores_low)

best_pred_high = np.argmin(errores_high)
worse_pred_high = np.argmax(errores_high)

print("Prediccion Best   LOW : " + str(comparacion_low["y_pred_low"][best_pred_low]) + " vs " + str(comparacion_low["y_real_low"][best_pred_low]) )
print("Prediccion Worse  LOW : " + str(comparacion_low["y_pred_low"][worse_pred_low]) + " vs " + str(comparacion_low["y_real_low"][worse_pred_low]) )

print("Prediccion Best   HIGH: " + str(comparacion_high["y_pred_high"][best_pred_high]) + " vs " + str(comparacion_high["y_real_high"][best_pred_high]) )
print("Prediccion Worse  HIGH: " + str(comparacion_high["y_pred_high"][worse_pred_high]) + " vs " + str(comparacion_high["y_real_high"][worse_pred_high]) )
# Out:
# Prediccion Best   LOW : 10625 vs 10626.0
# Prediccion Worse  LOW : 34138 vs 44961.09
# Prediccion Best   HIGH: 9697 vs 9700.0
# Prediccion Worse  HIGH: 38902 vs 46794.45
