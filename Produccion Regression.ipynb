# %%
# %reset -f
import sys
print("Python version")
print(sys.version)
# Out:
# Python version
# 3.7.9 (tags/v3.7.9:13c94747c7, Aug 17 2020, 18:58:18) [MSC v.1900 64 bit (AMD64)]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

import warnings
warnings.filterwarnings('ignore')

# %%
#Coingecko api
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %%
import time
import datetime

def edit_prices_dict(d): 
    df=pd.DataFrame(d)
    #Saving dates
    dates=df['prices'].map(lambda x: x[0])  
    #Filtering the values without dates
    df=df.applymap(lambda x: x[1])
    df['dates']=dates 
    df["dates"] = pd.to_datetime(df['dates'], unit='ms')
    df.index = df["dates"]
    df=df[['prices','total_volumes']]
    return df

# %%
#dd/mm/yyyy
from_date = "01/01/2021"
to_date = "21/12/2021"
from_unix = time.mktime(datetime.datetime.strptime(from_date, "%d/%m/%Y").timetuple())
to_unix = time.mktime(datetime.datetime.strptime(to_date, "%d/%m/%Y").timetuple())

token = "bitcoin"; vs_currency = "eur"

response=cg.get_coin_market_chart_range_by_id(id = token, vs_currency = vs_currency, from_timestamp = from_unix, to_timestamp = to_unix)

# %%
df = edit_prices_dict(response)
print(df.shape)
df.tail()
# Out:
# (342, 2)
#                   prices  total_volumes
# dates
# 2021-12-04  47537.221078   3.493493e+10
# 2021-12-05  43452.366271   4.944443e+10
# 2021-12-06  43584.415788   2.903941e+10
# 2021-12-07  44721.774318   3.201683e+10
# 2021-12-08  44927.870835   2.668591e+10

# %%
# Esto hay que hacerlo pues es con la info de hoy predecir mañana
lag_days = 1
df["y"] = df["prices"].shift(-1 * lag_days)
df.tail(5)
# Out:
#                   prices  total_volumes             y
# dates
# 2021-12-04  47537.221078   3.493493e+10  43452.366271
# 2021-12-05  43452.366271   4.944443e+10  43584.415788
# 2021-12-06  43584.415788   2.903941e+10  44721.774318
# 2021-12-07  44721.774318   3.201683e+10  44927.870835
# 2021-12-08  44927.870835   2.668591e+10           NaN

# %%
#https://towardsdatascience.com/building-a-comprehensive-set-of-technical-indicators-in-python-for-quantitative-trading-8d98751b5fb
# MovingAverage
values_ma = [5,15,30]

for i in values_ma:
    df["ma_close_" + str(i)] = df["prices"].rolling(window=i).mean()

# ExponentialMovingWindow
values_ema = [5,15,30]

for i in values_ema:
    df["ema_" + str(i)] = df["prices"].ewm(span = i, adjust = False).mean()
    
# RSI https://stackoverflow.com/questions/20526414/relative-strength-index-in-python-pandas
values_rsi = [7,14,21]
close = df['prices']

# Get the difference in price from previous step
delta = close.diff()

# Make the positive gains (up) and negative gains (down) Series
up, down = delta.copy(), delta.copy()
up[up < 0] = 0
down[down > 0] = 0

for i in values_rsi:
    # Calculate the EWMA
    #roll_up1 = up.ewm(span=i).mean()
    #roll_down1 = down.abs().ewm(span=i).mean()

    ## Calculate the RSI based on EWMA
    #RS1 = roll_up1 / roll_down1
    #RSI1 = 100.0 - (100.0 / (1.0 + RS1))

    # Calculate the SMA
    roll_up2 = up.rolling(i).mean()
    roll_down2 = down.abs().rolling(i).mean()

    # Calculate the RSI based on SMA
    RS2 = roll_up2 / roll_down2
    RSI2 = 100.0 - (100.0 / (1.0 + RS2))
    
    #df["rsi_ewma_" + str(i)] = RSI1.values
    df["rsi_sma_" + str(i)]  = RSI2.values
    
# BollingerBand
values_bollinger = [5,10,20]
for i in values_bollinger:
    df['bollinger_upper_' + str(i)] = df['prices'].rolling(window=i).mean() + (df['prices'].rolling(window=i).std()  * 2)
    df['bollinger_lower_' + str(i)] = df['prices'].rolling(window=i).mean() - (df['prices'].rolling(window=i).std()  * 2)

# %%
minus = 15 # Es el lag del pasado cuanto pillamos

# %%
all_columns = list(df.columns)
keep_columns = [item for item in all_columns if item not in "y"]
print(keep_columns)
# Out:
# ['prices', 'total_volumes', 'ma_close_5', 'ma_close_15', 'ma_close_30', 'ema_5', 'ema_15', 'ema_30', 'rsi_sma_7', 'rsi_sma_14', 'rsi_sma_21', 'bollinger_upper_5', 'bollinger_lower_5', 'bollinger_upper_10', 'bollinger_lower_10', 'bollinger_upper_20', 'bollinger_lower_20']

# %%
list_shift = list(range(1, minus))

for i in list_shift:
    for j in keep_columns:
        df[str(j) + "minus" + str(i)] = df[str(j)].shift(i)

# %%
print("Shape: " + str(df.shape))
df.dropna(inplace = True)
print("Shape: " + str(df.shape))
# Out:
# Shape: (342, 256)
# Shape: (298, 256)

# %%
df.tail(2)
# Out:
#                   prices  total_volumes             y    ma_close_5  \
# dates
# 2021-12-06  43584.415788   2.903941e+10  44721.774318  47011.014840
# 2021-12-07  44721.774318   3.201683e+10  44927.870835  45853.987593
#
#              ma_close_15   ma_close_30         ema_5        ema_15  \
# dates
# 2021-12-06  49371.101142  52225.487932  46122.579784  48977.364647
# 2021-12-07  48856.362776  51936.897134  45655.644629  48445.415856
#
#                   ema_30  rsi_sma_7  rsi_sma_14  rsi_sma_21  \
# dates
# 2021-12-06  50463.706406   9.646621   30.116551   29.538728
# 2021-12-07  50093.259175  15.539819   37.148210   32.896433
#
#             bollinger_upper_5  bollinger_lower_5  bollinger_upper_10  \
# dates
# 2021-12-06       53770.006835       40252.022844        53994.874544
# 2021-12-07       51511.703377       40196.271809        54142.650038
#
#             bollinger_lower_10  bollinger_upper_20  bollinger_lower_20  \
# dates
# 2021-12-06        42608.463203        55839.871311        44426.429384
# 2021-12-07        41894.834254        55672.101669        43725.594839
#
#             pricesminus1  total_volumesminus1  ma_close_5minus1  \
# dates
# 2021-12-06  43452.366271         4.944443e+10      48356.177998
# 2021-12-07  43584.415788         2.903941e+10      47011.014840
#
#             ma_close_15minus1  ma_close_30minus1   ema_5minus1  ema_15minus1  \
# dates
# 2021-12-06       50014.238557       52540.044945  47391.661782  49747.785913
# 2021-12-07       49371.101142       52225.487932  46122.579784  48977.364647
#
#             ema_30minus1  rsi_sma_7minus1  rsi_sma_14minus1  rsi_sma_21minus1  \
# dates
# 2021-12-06  50938.140242        28.947056         28.678468         31.058279
# 2021-12-07  50463.706406         9.646621         30.116551         29.538728
#
#             bollinger_upper_5minus1  bollinger_lower_5minus1  \
# dates
# 2021-12-06             54337.808479             42374.547516
# 2021-12-07             53770.006835             40252.022844
#
#             bollinger_upper_10minus1  bollinger_lower_10minus1  \
# dates
# 2021-12-06              54390.895479              44005.173130
# 2021-12-07              53994.874544              42608.463203
#
#             bollinger_upper_20minus1  bollinger_lower_20minus1  pricesminus2  \
# dates
# 2021-12-06              56220.472537              45313.090989  47537.221078
# 2021-12-07              55839.871311              44426.429384  43452.366271
#
#             total_volumesminus2  ma_close_5minus2  ma_close_15minus2  \
# dates
# 2021-12-06         3.493493e+10      49910.502712       50570.278887
# 2021-12-07         4.944443e+10      48356.177998       50014.238557
#
#             ma_close_30minus2   ema_5minus2  ema_15minus2  ema_30minus2  \
# dates
# 2021-12-06       52868.818397  49361.309538  50647.131576  51454.400516
# 2021-12-07       52540.044945  47391.661782  49747.785913  50938.140242
#
#             rsi_sma_7minus2  rsi_sma_14minus2  rsi_sma_21minus2  \
# dates
# 2021-12-06        49.910871         39.510688         35.659442
# 2021-12-07        28.947056         28.678468         31.058279
#
#             bollinger_upper_5minus2  bollinger_lower_5minus2  \
# dates
# 2021-12-06             52717.146961             47103.858462
# 2021-12-07             54337.808479             42374.547516
#
#             bollinger_upper_10minus2  bollinger_lower_10minus2  \
# dates
# 2021-12-06              53312.080755              46603.378978
# 2021-12-07              54390.895479              44005.173130
#
#             bollinger_upper_20minus2  bollinger_lower_20minus2  pricesminus3  \
# dates
# 2021-12-06              56526.411723              46399.635834  49974.160511
# 2021-12-07              56220.472537              45313.090989  47537.221078
#
#             total_volumesminus3  ma_close_5minus3  ma_close_15minus3  \
# dates
# 2021-12-06         3.209936e+10      50543.454256       50742.487482
# 2021-12-07         3.493493e+10      49910.502712       50570.278887
#
#             ma_close_30minus3   ema_5minus3  ema_15minus3  ema_30minus3  \
# dates
# 2021-12-06       53096.270756  50273.353768  51091.404504  51724.550822
# 2021-12-07       52868.818397  49361.309538  50647.131576  51454.400516
#
#             rsi_sma_7minus3  rsi_sma_14minus3  rsi_sma_21minus3  \
# dates
# 2021-12-06        37.521242         49.625574         38.094513
# 2021-12-07        49.910871         39.510688         35.659442
#
#             bollinger_upper_5minus3  bollinger_lower_5minus3  \
# dates
# 2021-12
#
#             bollinger_upper_5minus6  bollinger_lower_5minus6  \
# dates
# 2021-12-07             52846.009765              46338.63605
#
#             bollinger_upper_10minus6  bollinger_lower_10minus6  \
# dates
# 2021-12-07               53804.21552              47298.073068
#
#             bollinger_upper_20minus6  bollinger_lower_20minus6  pricesminus7  \
# dates
# 2021-12-07              58293.017225              46790.320303   51223.98984
#
#             total_volumesminus7  ma_close_5minus7  ma_close_15minus7  \
# dates
# 2021-12-07         2.743680e+10      50039.890611       51570.316351
#
#             ma_close_30minus7   ema_5minus7  ema_15minus7  ema_30minus7  \
# dates
# 2021-12-07       53419.626028  50416.339692  51506.893573  52049.797956
#
#             rsi_sma_7minus7  rsi_sma_14minus7  rsi_sma_21minus7  \
# dates
# 2021-12-07        54.592204         39.638563         37.630427
#
#             bollinger_upper_5minus7  bollinger_lower_5minus7  \
# dates
# 2021-12-07             54259.599431             45820.181792
#
#             bollinger_upper_10minus7  bollinger_lower_10minus7  \
# dates
# 2021-12-07              54499.820941              47186.716732
#
#             bollinger_upper_20minus7  bollinger_lower_20minus7  pricesminus8  \
# dates
# 2021-12-07              58785.597351              46930.281805    50701.9788
#
#             total_volumesminus8  ma_close_5minus8  ma_close_15minus8  \
# dates
# 2021-12-07         2.450117e+10       50004.95702       51980.530801
#
#             ma_close_30minus8   ema_5minus8  ema_15minus8  ema_30minus8  \
# dates
# 2021-12-07       53495.072106  50012.514617  51547.308391   52106.75024
#
#             rsi_sma_7minus8  rsi_sma_14minus8  rsi_sma_21minus8  \
# dates
# 2021-12-07        43.531658         36.588164         43.943993
#
#             bollinger_upper_5minus8  bollinger_lower_5minus8  \
# dates
# 2021-12-07             54178.289173             45831.624868
#
#             bollinger_upper_10minus8  bollinger_lower_10minus8  \
# dates
# 2021-12-07              54600.494413              47199.839537
#
#             bollinger_upper_20minus8  bollinger_lower_20minus8  pricesminus9  \
# dates
# 2021-12-07               59476.27353              46908.636236  48174.372723
#
#             total_volumesminus9  ma_close_5minus9  ma_close_15minus9  \
# dates
# 2021-12-07         2.496188e+10      50136.350652       52367.216892
#
#             ma_close_30minus9   ema_5minus9  ema_15minus9  ema_30minus9  \
# dates
# 2021-12-07       53600.776073  49667.782526  51668.069762  52203.631029
#
#             rsi_sma_7minus9  rsi_sma_14minus9  rsi_sma_21minus9  \
# dates
# 2021-12-07        28.421415         32.077374         41.541315
#
#             bollinger_upper_5minus9  bollinger_lower_5minus9  \
# dates
# 2021-12-07             54458.136071             45814.565232
#
#             bollinger_upper_10minus9  bollinger_lower_10minus9  \
# dates
# 2021-12-07              54574.322936              47109.685254
#
#             bollinger_upper_20minus9  bollinger_lower_20minus9  pricesminus10  \
# dates
# 2021-12-07              60146.569621               47003.98431   47551.041595
#
#             total_volumesminus10  ma_close_5minus10  ma_close_15minus10  \
# dates
# 2021-12-07          3.650689e+10       50531.604037        52909.111065
#
#             ma_close_30minus10  ema_5minus10  ema_15minus10  ema_30minus10  \
# dates
# 2021-12-07        53728.380461  50414.487427   52167.169339   52481.510912
#
#             rsi_sma_7minus10  rsi_sma_14minus10  rsi_sma_21minus10  \
# dates
# 2021-12-07         33.077029          30.815211          41.033523
#
#             bollinger_upper_5minus10  bollinger_lower_5minus10  \
# dates
# 2021-12-07              54279.610147              46783.597926
#
#             bollinger_upper_10minus10  bollinger_lower_10minus10  \
# dates
# 2021-12-07               54946.938811               47810.969913
#
#             bollinger_upper_20minus10  bollinger_lower_20minus10  \
# dates
# 2021-12-07               59964.244577               47827.704679
#
#             pricesminus11  total_volumesminus11  ma_close_5minus11  \
# dates
# 2021-12-07     52548.0701          3.008563e+10        51509.96568
#
#             ma_close_15minus11  ma_close_30minus11  ema_5minus11  \
# dates
# 2021-12-07         53524.78405        53828.566932  51846.210343
#
#             ema_15minus11  ema_30minus11  rsi_sma_7minus11  rsi_sma_14minus11  \
# dates
# 2021-12-07   52826.616159   52821.543279         63.181745          38.417668
#
#             rsi_sma_21minus11  bollinger_upper_5minus11  \
# dates
# 2021-12-07           48.51262              53517.626065
#
#             bollinger_lower_5minus11  bollinger_upper_10minus11  \
# dates
# 2021-12-07              49502.305295               54518.655891
#
#             bollinger_lower_10minus11  bollinger_upper_20minus11  \
# dates
# 2021-12-07               49410.607753               59483.345329
#
#             bollinger_lower_20minus11  pricesminus12  total_volumesminus12  \
# dates
# 2021-12-07               48891.449593   51049.321885          2.828809e+10
#
#             ma_close_5minus12  ma_close_15minus12  ma_close_30minus12  \
# dates
# 2021-12-07       51646.647061        53797.289234        53819.064328
#
#             ema_5minus12  ema_15minus12  ema_30minus12  rsi_sma_7minus12  \
# dates
# 2021-12-07  51495.280465   52866.408453   52840.403498         38.797005
#
#             rsi_sma_14minus12  rsi_sma_21minus12  bollinger_upper_5minus12  \
# dates
# 2021-12-07          33.518374          43.467693              54059.784369
#
#             bollinger_lower_5minus12  bollinger_upper_10minus12  \
# dates
# 2021-12-07              49233.509753               56070.385555
#
#             bollinger_lower_10minus12  bollinger_upper_20minus12  \
# dates
# 2021-12-07               48600.672886               59480.328824
#
#             bollinger_lower_20minus12  pricesminus13  total_volumesminus13  \
# dates
# 2021-12-07               48941.771706   51358.946958          3.239122e+10
#
#             ma_close_5minus13  ma_close_15minus13  ma_close_30minus13  \
# dates
# 2021-12-07        51795.37693        54254.954171        53932.702284
#
#             ema_5minus13  ema_15minus13  ema_30minus13  rsi_sma_7minus13  \
# dates
# 2021-12-07  51718.259755   53125.992249   52963.926368         40.652846
#
#             rsi_sma_14minus13  rsi_sma_21minus13  bollinger_upper_5minus13  \
# dates
# 2021-12-07          31.705481          43.546206              54114.265068
#
#             bollinger_lower_5minus13  bollinger_upper_10minus13  \
# dates
# 2021-12-07              49476.488793                57736.05932
#
#             bollinger_lower_10minus13  bollinger_upper_20minus13  \
# dates
# 2021-12-07               48200.576062               59401.322453
#
#             bollinger_lower_20minus13  pricesminus14  total_volumesminus14  \
# dates
# 2021-12-07               49247.402872   50150.639646          3.024101e+10
#
#             ma_close_5minus14  ma_close_15minus14  ma_close_30minus14  \
# dates
# 2021-12-07       51547.657538        54721.585737        53972.620642
#
#             ema_5minus14  ema_15minus14  ema_30minus14  rsi_sma_7minus14  \
# dates
# 2021-12-07  51897.916154    53378.42729   53074.614603          25.76973
#
#             rsi_sma_14minus14  rsi_sma_21minus14  bollinger_upper_5minus14  \
# dates
# 2021-12-07          26.073362          45.124337              54319.960158
#
#             bollinger_lower_5minus14  bollinger_upper_10minus14  \
# dates
# 2021-12-07              48775.354918               58577.262813
#
#             bollinger_lower_10minus14  bollinger_upper_20minus14  \
# dates
# 2021-12-07                48388.03721               59356.016489
#
#             bollinger_lower_20minus14
# dates
# 2021-12-07               49592.893324

# %%
# Crear pipeline
pipeline(train)

# %%
# Modelo
metrica = "MSE"
modelo = compare_models(sort = metrica, exclude = ["lar"] ,verbose = True)
# Out:
# <style type="text/css">
# #T_fcb54_ th {
#   text-align: left;
# }
# #T_fcb54_row0_col0, #T_fcb54_row0_col4, #T_fcb54_row1_col0, #T_fcb54_row1_col1, #T_fcb54_row1_col2, #T_fcb54_row1_col3, #T_fcb54_row1_col5, #T_fcb54_row1_col6, #T_fcb54_row2_col0, #T_fcb54_row2_col1, #T_fcb54_row2_col2, #T_fcb54_row2_col3, #T_fcb54_row2_col5, #T_fcb54_row2_col6, #T_fcb54_row3_col0, #T_fcb54_row3_col1, #T_fcb54_row3_col2, #T_fcb54_row3_col3, #T_fcb54_row3_col4, #T_fcb54_row3_col5, #T_fcb54_row3_col6, #T_fcb54_row4_col0, #T_fcb54_row4_col1, #T_fcb54_row4_col2, #T_fcb54_row4_col3, #T_fcb54_row4_col4, #T_fcb54_row4_col5, #T_fcb54_row4_col6, #T_fcb54_row5_col0, #T_fcb54_row5_col1, #T_fcb54_row5_col2, #T_fcb54_row5_col3, #T_fcb54_row5_col4, #T_fcb54_row5_col5, #T_fcb54_row5_col6, #T_fcb54_row6_col0, #T_fcb54_row6_col1, #T_fcb54_row6_col2, #T_fcb54_row6_col3, #T_fcb54_row6_col4, #T_fcb54_row6_col5, #T_fcb54_row6_col6, #T_fcb54_row7_col0, #T_fcb54_row7_col1, #T_fcb54_row7_col2, #T_fcb54_row7_col3, #T_fcb54_row7_col4, #T_fcb54_row7_col5, #T_fcb54_row7_col6, #T_fcb54_row8_col0, #T_fcb54_row8_col1, #T_fcb54_row8_col2, #T_fcb54_row8_col3, #T_fcb54_row8_col4, #T_fcb54_row8_col5, #T_fcb54_row8_col6, #T_fcb54_row9_col0, #T_fcb54_row9_col1, #T_fcb54_row9_col2, #T_fcb54_row9_col3, #T_fcb54_row9_col4, #T_fcb54_row9_col5, #T_fcb54_row9_col6, #T_fcb54_row10_col0, #T_fcb54_row10_col1, #T_fcb54_row10_col2, #T_fcb54_row10_col3, #T_fcb54_row10_col4, #T_fcb54_row10_col5, #T_fcb54_row10_col6, #T_fcb54_row11_col0, #T_fcb54_row11_col1, #T_fcb54_row11_col2, #T_fcb54_row11_col3, #T_fcb54_row11_col4, #T_fcb54_row11_col5, #T_fcb54_row11_col6, #T_fcb54_row12_col0, #T_fcb54_row12_col1, #T_fcb54_row12_col2, #T_fcb54_row12_col3, #T_fcb54_row12_col4, #T_fcb54_row12_col5, #T_fcb54_row12_col6, #T_fcb54_row13_col0, #T_fcb54_row13_col1, #T_fcb54_row13_col2, #T_fcb54_row13_col3, #T_fcb54_row13_col4, #T_fcb54_row13_col5, #T_fcb54_row13_col6, #T_fcb54_row14_col0, #T_fcb54_row14_col1, #T_fcb54_row14_col2, #T_fcb54_row14_col3, #T_fcb54_row14_col4, #T_fcb54_row14_col5, #T_fcb54_row14_col6, #T_fcb54_row15_col0, #T_fcb54_row15_col1, #T_fcb54_row15_col2, #T_fcb54_row15_col3, #T_fcb54_row15_col4, #T_fcb54_row15_col5, #T_fcb54_row15_col6, #T_fcb54_row16_col0, #T_fcb54_row16_col1, #T_fcb54_row16_col2, #T_fcb54_row16_col3, #T_fcb54_row16_col4, #T_fcb54_row16_col5, #T_fcb54_row16_col6 {
#   text-align: left;
# }
# #T_fcb54_row0_col1, #T_fcb54_row0_col2, #T_fcb54_row0_col3, #T_fcb54_row0_col5, #T_fcb54_row0_col6, #T_fcb54_row1_col4, #T_fcb54_row2_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fcb54_row0_col7, #T_fcb54_row2_col7, #T_fcb54_row3_col7, #T_fcb54_row4_col7, #T_fcb54_row5_col7, #T_fcb54_row6_col7, #T_fcb54_row7_col7, #T_fcb54_row8_col7, #T_fcb54_row9_col7, #T_fcb54_row10_col7, #T_fcb54_row11_col7, #T_fcb54_row12_col7, #T_fcb54_row13_col7, #T_fcb54_row14_col7, #T_fcb54_row15_col7, #T_fcb54_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fcb54_row1_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fcb54_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcb54_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_fcb54_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_fcb54_row0_col1" class="data row0 col1" >1141.7149</td>
#       <td id="T_fcb54_row0_col2" class="data row0 col2" >2340270.9553</td>
#       <td id="T_fcb54_row0_col3" class="data row0 col3" >1493.4285</td>
#       <td id="T_fcb54_row0_col4" class="data row0 col4" >0.9580</td>
#       <td id="T_fcb54_row0_col5" class="data row0 col5" >0.0392</td>
#       <td id="T_fcb54_row0_col6" class="data row0 col6" >0.0297</td>
#       <td id="T_fcb54_row0_col7" class="data row0 col7" >0.1230</td>
#     </tr>
#     <tr>
#       <th id="T_fcb54_level0_row1" class="row_heading level0 row1" >omp</th>
#       <td id="T_fcb54_row1_col0" class="data row1 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_fcb54_row1_col1" class="data row1 col1" >1189.5827</td>
#       <td id="T_fcb54_row1_col2" class="data row1 col2" >2347590.3979</td>
#       <td id="T_fcb54_row1_col3" class="data row1 col3" >1509.5196</td>
#       <td id="T_fcb54_row1_col4" class="data row1 col4" >0.9619</td>
#       <td id="T_fcb54_row1_col5" class="data row1 col5" >0.0404</td>
#       <td id="T_fcb54_row1_col6" class="data row1 col6" >0.0308</td>
#       <td id="T_fcb54_row1_col7" class="data row1 col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_fcb54_level0_row2" class="row_heading level0 row2" >llar</th>
#       <td id="T_fcb54_row2_col0" class="data row2 col0" >Lasso Least Angle Regression</td>
#       <td id="T_fcb54_row2_col1" class="data row2 col1" >1158.8700</td>
#       <td id="T_fcb54_row2_col2" class="data row2 col2" >2386388.6675</td>
#       <td id="T_fcb54_row2_col3" class="data row2 col3" >1522.7098</td>
#       <td id="T_fcb54_row2_col4" class="data row2 col4" >0.9619</td>
#       <td id="T_fcb54_row2_col5" class="data row2 col5" >0.0405</td>
#       <td id="T_fcb54_row2_col6" class="data row2 col6" >0.0300</td>
#       <td id="T_fcb54_row2_col7" class="data row2 col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_fcb54_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_fcb54_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_fcb54_row3_col1" class="data row3 col1" >1167.3367</td>
#       <td id="T_fcb54_row3_col2" class="data row3 col2" >2510483.7450</td>
#       <td id="T_fcb54_row3_col3" class="data row3 col3" >1536.6344</td>
#       <td id="T_fcb54_row3_col4" class="data row3 col4" >0.9540</td>
#       <td id="T_fcb54_row3_col5" class="data row3 col5" >0.0393</td>
#       <td id="T_fcb54_row3_col6" class="data row3 col6" >0.0300</td>
#       <td id="T_fcb54_row3_col7" class="data row3 col7" >0.1600</td>
#     </tr>
#     <tr>
#       <th id="T_fcb54_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_fcb54_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_fcb54_row4_col1" class="data row4 col1" >1230.5098</td>
#       <td id="T_fcb54_row4_col2" class="data row4 col2" >2638625.6444</td>
#       <td id="T_fcb54_row4_col3" class="data row4 col3" >1590.6915</td>
#       <td id="T_fcb54_row4_col4" class="data row4 col4" >0.9542</td>
#       <td id="T_fcb54_row4_col5" class="data row4 col5" >0.0407</td>
#       <td id="T_fcb54_row4_col6" class="data row4 col6" >0.0315</td>
#       <td id="T_fcb54_row4_col7" class="data row4 col7" >0.0630</td>
#     </tr>
#     <tr>
#       <th id="T_fcb54_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_fcb54_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_fcb54_row5_col1" class="data row5 col1" >1244.7265</td>
#       <td id="T_fcb54_row5_col2" class="data row5 col2" >2767930.0938</td>
#       <td id="T_fcb54_row5_col3" class="data row5 col3" >1627.8750</td>
#       <td id="T_fcb54_row5_col4" class="data row5 col4" >0.9550</td>
#       <td id="T_fcb54_row5_col5" class="data row5 col5" >0.0430</td>
#       <td id="T_fcb54_row5_col6" class="data row5 col6" >0.0322</td>
#       <td id="T_fcb54_row5_col7" class="data row5 col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_fcb54_level0_row6" class="row_heading level0 row6" >br</th>
#       <td id="T_fcb54_row6_col0" class="data row6 col0" >Bayesian Ridge</td>
#       <td id="T_fcb54_row6_col1" class="data row6 col1" >1272.0741</td>
#       <td id="T_fcb54_row6_col2" class="data row6 col2" >2789334.7906</td>
#       <td id="T_fcb54_row6

# %%
modelo = tune_model(modelo, search_algorithm = "tpe", search_library = "optuna", optimize = metrica, n_iter = 10,
                    tuner_verbose = False, choose_better = True, verbose = True )
# Out:
# <style type="text/css">
# #T_eabe7_row10_col0, #T_eabe7_row10_col1, #T_eabe7_row10_col2, #T_eabe7_row10_col3, #T_eabe7_row10_col4, #T_eabe7_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_eabe7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eabe7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eabe7_row0_col0" class="data row0 col0" >1040.6131</td>
#       <td id="T_eabe7_row0_col1" class="data row0 col1" >1424979.2400</td>
#       <td id="T_eabe7_row0_col2" class="data row0 col2" >1193.7249</td>
#       <td id="T_eabe7_row0_col3" class="data row0 col3" >0.9818</td>
#       <td id="T_eabe7_row0_col4" class="data row0 col4" >0.0368</td>
#       <td id="T_eabe7_row0_col5" class="data row0 col5" >0.0312</td>
#     </tr>
#     <tr>
#       <th id="T_eabe7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eabe7_row1_col0" class="data row1 col0" >1369.2266</td>
#       <td id="T_eabe7_row1_col1" class="data row1 col1" >3003859.2757</td>
#       <td id="T_eabe7_row1_col2" class="data row1 col2" >1733.1645</td>
#       <td id="T_eabe7_row1_col3" class="data row1 col3" >0.9517</td>
#       <td id="T_eabe7_row1_col4" class="data row1 col4" >0.0362</td>
#       <td id="T_eabe7_row1_col5" class="data row1 col5" >0.0292</td>
#     </tr>
#     <tr>
#       <th id="T_eabe7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eabe7_row2_col0" class="data row2 col0" >1153.8298</td>
#       <td id="T_eabe7_row2_col1" class="data row2 col1" >2981414.1551</td>
#       <td id="T_eabe7_row2_col2" class="data row2 col2" >1726.6772</td>
#       <td id="T_eabe7_row2_col3" class="data row2 col3" >0.9514</td>
#       <td id="T_eabe7_row2_col4" class="data row2 col4" >0.0468</td>
#       <td id="T_eabe7_row2_col5" class="data row2 col5" >0.0329</td>
#     </tr>
#     <tr>
#       <th id="T_eabe7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eabe7_row3_col0" class="data row3 col0" >1117.8199</td>
#       <td id="T_eabe7_row3_col1" class="data row3 col1" >2279754.8633</td>
#       <td id="T_eabe7_row3_col2" class="data row3 col2" >1509.8857</td>
#       <td id="T_eabe7_row3_col3" class="data row3 col3" >0.9677</td>
#       <td id="T_eabe7_row3_col4" class="data row3 col4" >0.0363</td>
#       <td id="T_eabe7_row3_col5" class="data row3 col5" >0.0263</td>
#     </tr>
#     <tr>
#       <th id="T_eabe7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eabe7_row4_col0" class="data row4 col0" >1348.5375</td>
#       <td id="T_eabe7_row4_col1" class="data row4 col1" >2578479.6637</td>
#       <td id="T_eabe7_row4_col2" class="data row4 col2" >1605.7645</td>
#       <td id="T_eabe7_row4_col3" class="data row4 col3" >0.9735</td>
#       <td id="T_eabe7_row4_col4" class="data row4 col4" >0.0460</td>
#       <td id="T_eabe7_row4_col5" class="data row4 col5" >0.0353</td>
#     </tr>
#     <tr>
#       <th id="T_eabe7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eabe7_row5_col0" class="data row5 col0" >1286.6595</td>
#       <td id="T_eabe7_row5_col1" class="data row5 col1" >2405909.8158</td>
#       <td id="T_eabe7_row5_col2" class="data row5 col2" >1551.0996</td>
#       <td id="T_eabe7_row5_col3" class="data row5 col3" >0.9563</td>
#       <td id="T_eabe7_row5_col4" class="data row5 col4" >0.0355</td>
#       <td id="T_eabe7_row5_col5" class="data row5 col5" >0.0295</td>
#     </tr>
#     <tr>
#       <th id="T_eabe7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eabe7_row6_col0" class="data row6 col0" >935.3217</td>
#       <td id="T_eabe7_row6_col1" class="data row6 col1" >1311892.3841</td>
#       <td id="T_eabe7_row6_col2" class="data row6 col2" >1145.3787</td>
#       <td id="T_eabe7_row6_col3" class="data row6 col3" >0.9836</td>
#       <td id="T_eabe7_row6_col4" class="data row6 col4" >0.0272</td>
#       <td id="T_eabe7_row6_col5" class="data row6 col5" >0.0233</td>
#     </tr>
#     <tr>
#       <th id="T_eabe7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eabe7_row7_col0" class="data row7 col0" >1268.4050</td>
#       <td id="T_eabe7_row7_col1" class="data row7 col1" >2982505.0728</td>
#       <td id="T_eabe7_row7_col2" class="data row7 col2" >1726.9931</td>
#       <td id="T_eabe7_row7_col3" class="data row7 col3" >0.9601</td>
#       <td id="T_eabe7_row7_col4" class="data row7 col4" >0.0476</td>
#       <td id="T_eabe7_row7_col5" class="data row7 col5" >0.0355</td>
#     </tr>
#     <tr>
#       <th id="T_eabe7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eabe7_row8_col0" class="data row8 col0" >866.6351</td>
#       <td id="T_eabe7_row8_col1" class="data row8 col1" >1265886.3655</td>
#       <td id="T_eabe7_row8_col2" class="data row8 col2" >1125.1162</td>
#       <td id="T_eabe7_row8_col3" class="data row8 col3" >0.9808</td>
#       <td id="T_eabe7_row8_col4" class="data row8 col4" >0.0302</td>
#       <td id="T_eabe7_row8_col5" class="data row8 col5" >0.0214</td>
#     </tr>
#     <tr>
#       <th id="T_eabe7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eabe7_row9_col0" class="data row9 col0" >1623.1963</td>
#       <td id="T_eabe7_row9_col1" class="data row9 col1" >4886974.1858</td>
#       <td id="T_eabe7_row9_col2" class="data row9 col2" >2210.6502</td>
#       <td id="T_eabe7_row9_col3" class="data row9 col3" >0.8522</td>
#       <td id="T_eabe7_row9_col4" class="data row9 col4" >0.0647</td>
#       <td id="T_eabe7_row9_col5" class="data row9 col5" >0.0473</td>
#     </tr>
#     <tr>
#       <th id="T_eabe7_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_eabe7_row10_col0" class="data row10 col0" >1201.0244</td>
#       <td id="T_eabe7_row10_col1" class="data row10 col1" >2512165.5022</td>
#       <td id="T_eabe7_row10_col2" class="data row10 col2" >1552.8455</td>
#       <td id="T_eabe7_row10_col3" class="data row10 col3" >0.9559</td>
#       <td id="T_eabe7_row10_col4" class="data row10 col4" >0.0407</td>
#       <td id="T_eabe7_row10_col5" class="data row10 col5" >0.0312</td>
#     </tr>
#     <tr>
#       <th id="T_eabe7_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_eabe7_row11_col0" class="data row11 col0" >213.8811</td>
#       <td id="T_eabe7_row11_col1" class="data row11 col1" >1028029.0082</td>
#       <td id="T_eabe7_row11_col2" class="data row11 col2" >317.5476</td>
#       <td id="T_eabe7_row11_col3" class="data row11 col3" >0.0365</td>
#       <td id="T_eabe7_row11_col4" class="data row11 col4" >0.0103</td>
#       <td id="T_eabe7_row11_col5" class="data row11 col5" >0.0070</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_modelo = finalize_model(modelo)

# %%
prediccion = predict_model(final_modelo, data = test)

# %%
import telepot

bot_token = '1653124784:AAFpL0qlC_ybadcbFX6jKagauRFpiFpSf1E'
chatID = '-1001701018194'

bot = telepot.Bot(bot_token)

# %%
from datetime import datetime

# %%
mensaje = "BTC : " + str(prediccion["Label"][0].round(2)) + " EUR at " + str(datetime.today().strftime('%d-%m-%Y'))
print(mensaje)
# Out:
# BTC : 44910.39 EUR at 08-12-2021

# %%
bot.sendMessage(chatID, mensaje)
# Out:
# {'message_id': 14,
#  'from': {'id': 1653124784,
#   'is_bot': True,
#   'first_name': 'JARVIS',
#   'username': 'JARVIS_Walkn_bot'},
#  'chat': {'id': -1001701018194,
#   'title': 'MoneyIsJustANumber',
#   'type': 'supergroup'},
#  'date': 1638958233,
#  'text': 'BTC : 44910.39 EUR at 08-12-2021'}
