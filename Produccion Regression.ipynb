# %%
# %reset -f
import sys
print("Python version")
print(sys.version)
# Out:
# Python version
# 3.7.9 (tags/v3.7.9:13c94747c7, Aug 17 2020, 18:58:18) [MSC v.1900 64 bit (AMD64)]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

import warnings
warnings.filterwarnings('ignore')

# %%
#Coingecko api
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %%
import time
import datetime

def edit_prices_dict(d): 
    df=pd.DataFrame(d)
    #Saving dates
    dates=df['prices'].map(lambda x: x[0])  
    #Filtering the values without dates
    df=df.applymap(lambda x: x[1])
    df['dates']=dates 
    df["dates"] = pd.to_datetime(df['dates'], unit='ms')
    df.index = df["dates"]
    df=df[['prices','total_volumes']]
    return df

# %%
#dd/mm/yyyy
from_date = "01/01/2021"
to_date = "17/01/2022"
from_unix = time.mktime(datetime.datetime.strptime(from_date, "%d/%m/%Y").timetuple())
to_unix = time.mktime(datetime.datetime.strptime(to_date, "%d/%m/%Y").timetuple())

token = "filecoin"; vs_currency = "eur"

response=cg.get_coin_market_chart_range_by_id(id = token, vs_currency = vs_currency, from_timestamp = from_unix, to_timestamp = to_unix)

# %%
df = edit_prices_dict(response)
print(df.shape)
df.tail()
# Out:
# (381, 2)
#                prices  total_volumes
# dates
# 2022-01-12  25.432227   2.859746e+08
# 2022-01-13  26.907742   3.247424e+08
# 2022-01-14  25.020430   3.138200e+08
# 2022-01-15  26.078130   3.360830e+08
# 2022-01-16  26.100749   2.331849e+08

# %%
# Esto hay que hacerlo pues es con la info de hoy predecir mañana
lag_days = 1
df["y"] = df["prices"].shift(-1 * lag_days)
df.tail(5)
# Out:
#                prices  total_volumes          y
# dates
# 2022-01-12  25.432227   2.859746e+08  26.907742
# 2022-01-13  26.907742   3.247424e+08  25.020430
# 2022-01-14  25.020430   3.138200e+08  26.078130
# 2022-01-15  26.078130   3.360830e+08  26.100749
# 2022-01-16  26.100749   2.331849e+08        NaN

# %%
#https://towardsdatascience.com/building-a-comprehensive-set-of-technical-indicators-in-python-for-quantitative-trading-8d98751b5fb
# MovingAverage
values_ma = [5,15,30]

for i in values_ma:
    df["ma_close_" + str(i)] = df["prices"].rolling(window=i).mean()

# ExponentialMovingWindow
values_ema = [5,15,30]

for i in values_ema:
    df["ema_" + str(i)] = df["prices"].ewm(span = i, adjust = False).mean()
    
# RSI https://stackoverflow.com/questions/20526414/relative-strength-index-in-python-pandas
values_rsi = [7,14,21]
close = df['prices']

# Get the difference in price from previous step
delta = close.diff()

# Make the positive gains (up) and negative gains (down) Series
up, down = delta.copy(), delta.copy()
up[up < 0] = 0
down[down > 0] = 0

for i in values_rsi:
    # Calculate the EWMA
    #roll_up1 = up.ewm(span=i).mean()
    #roll_down1 = down.abs().ewm(span=i).mean()

    ## Calculate the RSI based on EWMA
    #RS1 = roll_up1 / roll_down1
    #RSI1 = 100.0 - (100.0 / (1.0 + RS1))

    # Calculate the SMA
    roll_up2 = up.rolling(i).mean()
    roll_down2 = down.abs().rolling(i).mean()

    # Calculate the RSI based on SMA
    RS2 = roll_up2 / roll_down2
    RSI2 = 100.0 - (100.0 / (1.0 + RS2))
    
    #df["rsi_ewma_" + str(i)] = RSI1.values
    df["rsi_sma_" + str(i)]  = RSI2.values
    
# BollingerBand
values_bollinger = [5,10,20]
for i in values_bollinger:
    df['bollinger_upper_' + str(i)] = df['prices'].rolling(window=i).mean() + (df['prices'].rolling(window=i).std()  * 2)
    df['bollinger_lower_' + str(i)] = df['prices'].rolling(window=i).mean() - (df['prices'].rolling(window=i).std()  * 2)

# %%
minus = 15 # Es el lag del pasado cuanto pillamos

# %%
all_columns = list(df.columns)
keep_columns = [item for item in all_columns if item not in "y"]
print(keep_columns)
# Out:
# ['prices', 'total_volumes', 'ma_close_5', 'ma_close_15', 'ma_close_30', 'ema_5', 'ema_15', 'ema_30', 'rsi_sma_7', 'rsi_sma_14', 'rsi_sma_21', 'bollinger_upper_5', 'bollinger_lower_5', 'bollinger_upper_10', 'bollinger_lower_10', 'bollinger_upper_20', 'bollinger_lower_20']

# %%
list_shift = list(range(1, minus))

for i in list_shift:
    for j in keep_columns:
        df[str(j) + "minus" + str(i)] = df[str(j)].shift(i)

# %%
print("Shape: " + str(df.shape))
df.dropna(inplace = True)
print("Shape: " + str(df.shape))
# Out:
# Shape: (381, 256)
# Shape: (337, 256)

# %%
df.tail(2)
# Out:
#               prices  total_volumes          y  ma_close_5  ma_close_15  \
# dates
# 2022-01-14  25.02043   3.138200e+08  26.078130   25.779868    28.580394
# 2022-01-15  26.07813   3.360830e+08  26.100749   25.660432    28.264417
#
#             ma_close_30      ema_5     ema_15     ema_30  rsi_sma_7  \
# dates
# 2022-01-14    30.423243  26.022584  28.094500  30.822085  28.692124
# 2022-01-15    30.163986  26.041099  27.842453  30.516024  41.189002
#
#             rsi_sma_14  rsi_sma_21  bollinger_upper_5  bollinger_lower_5  \
# dates
# 2022-01-14   32.788127   34.043344          27.680135          23.879601
# 2022-01-15   38.000572   38.018004          27.341749          23.979114
#
#             bollinger_upper_10  bollinger_lower_10  bollinger_upper_20  \
# dates
# 2022-01-14           32.080082           22.617899           35.440246
# 2022-01-15           30.012984           23.451832           35.100486
#
#             bollinger_lower_20  pricesminus1  total_volumesminus1  \
# dates
# 2022-01-14           23.671729     26.907742         3.247424e+08
# 2022-01-15           23.344173     25.020430         3.138200e+08
#
#             ma_close_5minus1  ma_close_15minus1  ma_close_30minus1  \
# dates
# 2022-01-14         25.950129          28.922588          30.674998
# 2022-01-15         25.779868          28.580394          30.423243
#
#             ema_5minus1  ema_15minus1  ema_30minus1  rsi_sma_7minus1  \
# dates
# 2022-01-14    26.523661     28.533652     31.222199        34.461150
# 2022-01-15    26.022584     28.094500     30.822085        28.692124
#
#             rsi_sma_14minus1  rsi_sma_21minus1  bollinger_upper_5minus1  \
# dates
# 2022-01-14         39.609647         40.774648                27.652411
# 2022-01-15         32.788127         34.043344                27.680135
#
#             bollinger_lower_5minus1  bollinger_upper_10minus1  \
# dates
# 2022-01-14                24.247846                 32.877731
# 2022-01-15                23.879601                 32.080082
#
#             bollinger_lower_10minus1  bollinger_upper_20minus1  \
# dates
# 2022-01-14                 23.016380                 35.498464
# 2022-01-15                 22.617899                 35.440246
#
#             bollinger_lower_20minus1  pricesminus2  total_volumesminus2  \
# dates
# 2022-01-14                 24.328337     25.432227         2.859746e+08
# 2022-01-15                 23.671729     26.907742         3.247424e+08
#
#             ma_close_5minus2  ma_close_15minus2  ma_close_30minus2  \
# dates
# 2022-01-14         26.118377          29.268012          30.838641
# 2022-01-15         25.950129          28.922588          30.674998
#
#             ema_5minus2  ema_15minus2  ema_30minus2  rsi_sma_7minus2  \
# dates
# 2022-01-14    26.331620     28.765925     31.519748        14.359214
# 2022-01-15    26.523661     28.533652     31.222199        34.461150
#
#             rsi_sma_14minus2  rsi_sma_21minus2  bollinger_upper_5minus2  \
# dates
# 2022-01-14         29.298914         37.531283                28.371172
# 2022-01-15         39.609647         40.774648                27.652411
#
#             bollinger_lower_5minus2  bollinger_upper_10minus2  \
# dates
# 2022-01-14                23.865582                 33.744888
# 2022-01-15                24.247846                 32.877731
#
#             bollinger_lower_10minus2  bollinger_upper_20minus2  \
# dates
# 2022-01-14                 23.067471                 35.790948
# 2022-01-15                 23.016380                 35.498464
#
#             bollinger_lower_20minus2  pricesminus3  total_volumesminus3  \
# dates
# 2022-01-14                 24.653759     24.863630         4.994748e+08
# 2022-01-15                 24.328337     25.432227         2.859746e+08
#
#             ma_close_5minus3  ma_close_15minus3  ma_close_30minus3  \
# dates
# 2022-01-14         26.881941          29.878337          31.164648
# 2022-01-15         26.118377          29.268012          30.838641
#
#             ema_5minus3  ema_15minus3  ema_30minus3  rsi_sma_7minus3  \
# dates
# 2022-01-14    26.781317     29.242168     31.939577        20.003771
# 2022-01-15    26.331620     28.765925     31.519748        14.359214
#
#             rsi_sma_14minus3  rsi_sma_21minus3  bollinger_upper_5minus3  \
# dates
# 2022-01-14         23.002307         37.023824                30.272587
# 2022-01-15         29.298914         37.531283                28.371172
#
#             bollinger_lower_5minus3  bollinger_upper_10minus3  \
# dates
# 2022-01-14                23.491294                 34.279552
# 2022-01-15                23.865582                 33.744888
#
#             bollinger_lower_10minus3  bollinger_upper_20minus3  \
# dates
# 2022-01-14                 23.779310                 35.639170
# 2022-01-15                 23.067471                 35.790948
#
#             bollinger_lower_20minus3  pricesminus4  total_volumesminus4  \
# dates
# 2022-01-14                 25.413655     26.675313         2.698768e+08
# 2022-01-15                 24.653759     24.863630         4.994748e+08
#
#             ma_close_5minus4  ma_close_15minus4  ma_close_30minus4  \
# dates
# 2022-01-14         27.804384          30.409629          31.522319
# 2022-01-15         26.881941          29.878337          31.164648
#
#             ema_5minus4  ema_15minus4  ema_30minus4  rsi_sma_7minus4  \
# dates
# 2022-01-14    27.740161     29.867673     32.427573        22.951151
# 2022-01-15    26.781317     29.242168     31.939577        20.003771
#
#             rsi_sma_14minus4  rsi_sma_21minus4  bollinger_upper_5minus4  \
# dates
# 2022-01-14         32.847987         38.600534                30.950293
# 2022-01-15         23.002307         37.023824                30.272587
#
#             bollinger_lower_5minus4  bollinger_upper_10minus4  \
# dates
# 2022-01-14                24.658475                 33.949746
# 2022-01-15                23.491294                 34.279552
#
#             bollinger_lower_10minus4  bollinger_upper_20minus4  \
# dates
# 2022-01-14                 25.183073                  35.21867
# 2022-01-15                 23.779310                  35.63917
#
#             bollinger_lower_20minus4  pricesminus5  total_volumesminus5  \
# dates
# 2022-01-14                 26.481183     25.871730         3.793455e+08
# 2022-01-15                 25.413655     26.675313         2.698768e+08
#
#             ma_close_5minus5  ma_close_15minus5  ma_close_30minus5  \
# dates
# 2022-01-14         28.918113          30.814693          31.817636
# 2022-01-15         27.804384          30.409629          31.522319
#
#             ema_5minus5  ema_15minus5  ema_30minus5  rsi_sma_7minus5  \
# dates
# 2022-01-14    28.272585     30.323725     32.824281        15.012834
# 2022-01-15    27.740161     29.867673     32.427573        22.951151
#
#             rsi_sma_14minus5  rsi_sma_21minus5  bollinger_upper_5minus5  \
# dates
# 2022-01-14         30.034418         35.542407                33.622345
# 2022-01-15         32.847987         38.600534                30.950293
#
#             bollinger_lower_5minus5  bollinger_upper_10minus5  \
# dates
# 2022-01-14                24.213881                 33.909027
# 2022-01-15                24.658475                 33.949746
#
#             bollinger_lower_10minus5  bollinger_upper_20minus5  \
# dates
# 2022-01-14                 26.052288                 34.966073
# 2022-01-15                 25.183073                 35.218670
#
#             bollinger_lower_20minus5  pricesminus6  total_volumesminus6  \
# dates
# 2022-01-14                 27.161850     27.748985         5.717897e+08
# 2022-01-15                 26.481183     25.871730         3.793455e+08
#
#             ma_close_5minus6  ma_close_15minus6  ma_close_30minus6  \
# dates
# 2022-01-14         29.943983          31.234491          32.065079
# 2022-01-15         28.918113          30.814693          31.817636
#
#             ema_5minus6  ema_15minus6  ema_30minus6  rsi_sma_7minus6  \
# dates
# 2022-01-14    29.473012     30.959724     33.303767        34.140983
# 2022-01-15    28.272585     30.323725     32.824281        15.012834
#
#             rsi_sma_14minus6  rsi_sma_21minus6  bollinger_upper_5minus6  \
# dates
# 2022-01-14         36.131060         40.342688                33.397396
# 2022-01-15         30.034418         35.542407                33.622345
#
#             bollinger_lower_5minus6  bollinger_upper_10minus6  \
# dates
# 2022-01-14                26.490570                 33.078443
# 2022-01-15                24.213881                 33.909027
#
#             bollinger_lower_10minus6  bollinger_upper_20minus6  \
# dates
# 2022-01-14                 27.739193                 34.409848
# 2022-01-15                 26.052288                 34.966073
#
#             bollinger_lower_20minus6  pricesminus7  total_volumesminus7  \
# dates
# 2022-01-14                 28.311783     29.250045         4.600583e+08
# 2022-01-15                 27.161850     27.748985         5.717897e+08
#
#             ma_close_5minus7  ma_close_15minus7  ma_close_30minus7  \
# dates
# 2022-01-14         30.693983          31.590346          32.357214
# 2022-01-15         29.943983          31.234491          32.065079
#
#             ema_5minus7  ema_15minus7  ema_30minus7  rsi_sma_7minus7  \
# dates
# 2022-01-14    30.335025     31.418401     33.686856        38.666071
# 2022-01-15    29.473012     30.959724     33.303767        34.140983
#
#             rsi_sma_14minus7  rsi_sma_21minus7  bollinger_upper_5minus7  \
# dates
# 2022-01-14         37.503135         41.296093                33.285038
# 2022-01-15         36.131060         40.342688                33.397396
#
#             bollinger_lower_5minus7  bollinger_upper_10minus7  \
# dates
# 2022-01-14                28.102927                 32.940500
# 2022-01-15                26.490570                 33.078443
#
#             bollinger_lower_10minus7  bollinger_upper_20minus7  \
# dates
# 2022-01-14                 28.745159                 34.140173
# 2022-01-15                 27.739193                 34.409848
#
#             bollinger_lower_20minus7  pricesminus8  total_volumesminus8  \
# dates
# 2022-01-14                 29.035442     29.475846         7.931207e+08
# 2022-01-15                 28.311783     29.250045         4.600583e+08
#
#             ma_close_5minus8  ma_close_15minus8  ma_close_30minus8  \
# dates
# 2022-01-14         31.176922          31.741236          32.540246
# 2022-01-15         30.693983          31.590346          32.357214
#
#             ema_5minus8  ema_15minus8  ema_30minus8  rsi_sma_7minus8  \
# dates
# 2022-01-14    30.877515     31.728166     33.992843        45.394230
# 2022-01-15    30.335025     31.418401     33.686856        38.666071
#
#             rsi_sma_14minus8  rsi_sma_21minus8  bollinger_upper_5minus8  \
# dates
# 2022-01-14         43.898975         39.664094                33.275692
# 2022-01-15         37.503135         41.296093                33.285038
#
#             bollinger_lower_5minus8  bollinger_upper_10minus8  \
# dates
# 2022-01-14                29.078152                 34.246662
# 2022-01-15                28.102927                 32.940500
#
#             bollinger_lower_10minus8  bollinger_upper_20minus8  \
# dates
# 2022-01-14                 28.506408                 34.017024
# 2022-01-15                 28.745159                 34.140173
#
#             bollinger_lower_20minus8  pricesminus9  total_volumesminus9  \
# dates
# 2022-01-14                 29.410844     32.243958         6.206385e+08
# 2022-01-15                 29.035442     29.475846         7.931207e+08
#
#             ma_close_5minus9  ma_close_15minus9  ma_close_30minus9  \
# dates
# 2022-01-14         31.328435          31.865107          32.702529
# 2022-01-15         31.176922          31.741236          32.540246
#
#             ema_5minus9  ema_15minus9  ema_30minus9  rsi_sma_7minus9  \
# dates
# 2022-01-14    31.578349     32.049926     34.304360        51.187107
# 2022-01-15    30.877515     31.728166     33.992843        45.394230
#
#             rsi_sma_14minus9  rsi_sma_21minus9  bollinger_upper_5minus9  \
# dates
# 2022-01-14         53.224857         49.164767                32.840590
# 2022-01-15         43.898975         39.664094                33.275692
#
#             bollinger_lower_5minus9  bollinger_upper_10minus9  \
# dates
# 2022-01-14                29.816279                 34.371935
# 2022-01-15                29.078152                 34.246662
#
#             bollinger_lower_10minus9  bollinger_upper_20minus9  \
# dates
# 2022-01-14                 29.052567                 33.972352
# 2022-01-15                 28.506408                 34.017024
#
#             bollinger_lower_20minus9  pricesminus10  total_volumesminus10  \
# dates
# 2022-01-14                 29.787199      31.001081          2.769506e+08
# 2022-01-15                 29.410844      32.243958          6.206385e+08
#
#             ma_close_5minus10  ma_close_15minus10  ma_close_30minus10  \
# dates
# 2022-01-14          31.043202           31.779244           32.780153
# 2022-01-15          31.328435           31.865107           32.702529
#
#             ema_5minus10  ema_15minus10  ema_30minus10  rsi_sma_7minus10  \
# dates
# 2022-01-14     31.245545      32.022207      34.446456         26.946477
# 2022-01-15     31.578349      32.049926      34.304360         51.187107
#
#             rsi_sma_14minus10  rsi_sma_21minus10  bollinger_upper_5minus10  \
# dates
# 2022-01-14          50.170129          47.876946                 32.184427
# 2022-01-15          53.224857          49.164767                 32.840590
#
#             bollinger_lower_5minus10  bollinger_upper_10minus10  \
# dates
# 2022-01-14                 29.901976                  34.486335
# 2022-01-15                 29.816279                  34.371935
#
#             bollinger_lower_10minus10  bollinger_upper_20minus10  \
# dates
# 2022-01-14                  29.039632                  34.228776
# 2022-01-15                  29.052567                  33.972352
#
#             bollinger_lower_20minus10  pricesminus11  total_volumesminus11  \
# dates
# 2022-01-14                  29.691963      31.498982          2.637016e+08
# 2022-01-15                  29.787199      31.001081          2.769506e+08
#
#             ma_close_5minus11  ma_close_15minus11  ma_close_30minus11  \
# dates
# 2022-01-14          30.873653           31.833093           32.952822
# 2022-01-15          31.043202           31.779244           32.780153
#
#             ema_5minus11  ema_15minus11  ema_30minus11  rsi_sma_7minus11  \
# dates
# 2022-01-14     31.367777      32.168083      34.684068         42.616440
# 2022-01-15     31.245545      32.022207      34.446456         26.946477
#
#             rsi_sma_14minus11  rsi_sma_21minus11  bollinger_upper_5minus11  \
# dates
# 2022-01-14          48.860922          41.603678                 32.269627
# 2022-01-15          50.170129          47.876946                 32.184427
#
#             bollinger_lower_5minus11  bollinger_upper_10minus11  \
# dates
# 2022-01-14                 29.477679                  34.557656
# 2022-01-15                 29.901976                  34.486335
#
#             bollinger_lower_10minus11  bollinger_upper_20minus11  \
# dates
# 2022-01-14                  29.201834                  34.276146
# 2022-01-15                  29.039632                  34.228776
#
#             bollinger_lower_20minus11  pricesminus12  total_volumesminus12  \
# dates
# 2022-01-14                  29.801793      31.664742          2.358454e+08
# 2022-01-15                  29.691963      31.498982          2.637016e+08
#
#             ma_close_5minus12  ma_close_15minus12  ma_close_30minus12  \
# dates
# 2022-01-14          30.991677           31.885749           33.368396
# 2022-01-15          30.873653           31.833093           32.952822
#
#             ema_5minus12  ema_15minus12  ema_30minus12  rsi_sma_7minus12  \
# dates
# 2022-01-14     31.302174      32.263668      34.903730          43.92980
# 2022-01-15     31.367777      32.168083      34.684068          42.61644
#
#             rsi_sma_14minus12  rsi_sma_21minus12  bollinger_upper_5minus12  \
# dates
# 2022-01-14          47.757370          41.202014                 32.713703
# 2022-01-15          48.860922          41.603678                 32.269627
#
#             bollinger_lower_5minus12  bollinger_upper_10minus12  \
# dates
# 2022-01-14                 29.269651                  34.802994
# 2022-01-15                 29.477679                  34.557656
#
#             bollinger_lower_10minus12  bollinger_upper_20minus12  \
# dates
# 2022-01-14                  29.274061                  34.280378
# 2022-01-15                  29.201834                  34.276146
#
#             bollinger_lower_20minus12  pricesminus13  total_volumesminus13  \
# dates
# 2022-01-14                  29.829365      30.233410          4.169757e+08
# 2022-01-15                  29.801793      31.664742          2.358454e+08
#
#             ma_close_5minus13  ma_close_15minus13  ma_close_30minus13  \
# dates
# 2022-01-14          31.576148           31.892937           33.895426
# 2022-01-15          30.991677           31.885749           33.368396
#
#             ema_5minus13  ema_15minus13  ema_30minus13  rsi_sma_7minus13  \
# dates
# 2022-01-14     31.120890      32.349229      35.127108         38.055263
# 2022-01-15     31.302174      32.263668      34.903730         43.929800
#
#             rsi_sma_14minus13  rsi_sma_21minus13  bollinger_upper_5minus13  \
# dates
# 2022-01-14          44.079677          37.351497                 35.281735
# 2022-01-15          47.757370          41.202014                 32.713703
#
#             bollinger_lower_5minus13  bollinger_upper_10minus13  \
# dates
# 2022-01-14                 27.870560                  34.798590
# 2022-01-15                 29.269651                  34.802994
#
#             bollinger_lower_10minus13  bollinger_upper_20minus13  \
# dates
# 2022-01-14                  29.248197                  34.856630
# 2022-01-15                  29.274061                  34.280378
#
#             bollinger_lower_20minus13  pricesminus14  total_volumesminus14  \
# dates
# 2022-01-14                  29.607881      30.817792          4.111008e+08
# 2022-01-15                  29.829365      30.233410          4.169757e+08
#
#             ma_close_5minus14  ma_close_15minus14  ma_close_30minus14  \
# dates
# 2022-01-14          32.096068           32.063556           34.489785
# 2022-01-15          31.576148           31.892937           33.895426
#
#             ema_5minus14  ema_15minus14  ema_30minus14  rsi_sma_7minus14  \
# dates
# 2022-01-14      31.56463      32.651489      35.464604         36.549571
# 2022-01-15      31.12089      32.349229      35.127108         38.055263
#
#             rsi_sma_14minus14  rsi_sma_21minus14  bollinger_upper_5minus14  \
# dates
# 2022-01-14          42.650026          44.522378                 35.582693
# 2022-01-15          44.079677          37.351497                 35.281735
#
#             bollinger_lower_5minus14  bollinger_upper_10minus14  \
# dates
# 2022-01-14                 28.609444                  34.670204
# 2022-01-15                 27.870560                  34.798590
#
#             bollinger_lower_10minus14  bollinger_upper_20minus14  \
# dates
# 2022-01-14                  29.596683                   35.35030
# 2022-01-15                  29.248197                   34.85663
#
#             bollinger_lower_20minus14
# dates
# 2022-01-14                  29.650248
# 2022-01-15                  29.607881

# %%
# Importing module and initializing setup
from pycaret.regression import *

def pipeline(df):
    modelo = setup(data = df,
                   target = 'y', feature_interaction = False,
                   remove_outliers=True,
                   normalize = True, normalize_method = "zscore",
                   silent = True, verbose=False);

# %%
past_t = 250 # Es hiperparametro del modelo

# %%
# Train
train = df.iloc[len(df) - past_t - 1 : len(df) - 1]
print("Shape: " + str(train.shape))
train.tail(1)
# Out:
# Shape: (250, 256)
#               prices  total_volumes         y  ma_close_5  ma_close_15  \
# dates
# 2022-01-14  25.02043   3.138200e+08  26.07813   25.779868    28.580394
#
#             ma_close_30      ema_5   ema_15     ema_30  rsi_sma_7  rsi_sma_14  \
# dates
# 2022-01-14    30.423243  26.022584  28.0945  30.822085  28.692124   32.788127
#
#             rsi_sma_21  bollinger_upper_5  bollinger_lower_5  \
# dates
# 2022-01-14   34.043344          27.680135          23.879601
#
#             bollinger_upper_10  bollinger_lower_10  bollinger_upper_20  \
# dates
# 2022-01-14           32.080082           22.617899           35.440246
#
#             bollinger_lower_20  pricesminus1  total_volumesminus1  \
# dates
# 2022-01-14           23.671729     26.907742         3.247424e+08
#
#             ma_close_5minus1  ma_close_15minus1  ma_close_30minus1  \
# dates
# 2022-01-14         25.950129          28.922588          30.674998
#
#             ema_5minus1  ema_15minus1  ema_30minus1  rsi_sma_7minus1  \
# dates
# 2022-01-14    26.523661     28.533652     31.222199         34.46115
#
#             rsi_sma_14minus1  rsi_sma_21minus1  bollinger_upper_5minus1  \
# dates
# 2022-01-14         39.609647         40.774648                27.652411
#
#             bollinger_lower_5minus1  bollinger_upper_10minus1  \
# dates
# 2022-01-14                24.247846                 32.877731
#
#             bollinger_lower_10minus1  bollinger_upper_20minus1  \
# dates
# 2022-01-14                  23.01638                 35.498464
#
#             bollinger_lower_20minus1  pricesminus2  total_volumesminus2  \
# dates
# 2022-01-14                 24.328337     25.432227         2.859746e+08
#
#             ma_close_5minus2  ma_close_15minus2  ma_close_30minus2  \
# dates
# 2022-01-14         26.118377          29.268012          30.838641
#
#             ema_5minus2  ema_15minus2  ema_30minus2  rsi_sma_7minus2  \
# dates
# 2022-01-14     26.33162     28.765925     31.519748        14.359214
#
#             rsi_sma_14minus2  rsi_sma_21minus2  bollinger_upper_5minus2  \
# dates
# 2022-01-14         29.298914         37.531283                28.371172
#
#             bollinger_lower_5minus2  bollinger_upper_10minus2  \
# dates
# 2022-01-14                23.865582                 33.744888
#
#             bollinger_lower_10minus2  bollinger_upper_20minus2  \
# dates
# 2022-01-14                 23.067471                 35.790948
#
#             bollinger_lower_20minus2  pricesminus3  total_volumesminus3  \
# dates
# 2022-01-14                 24.653759      24.86363         4.994748e+08
#
#             ma_close_5minus3  ma_close_15minus3  ma_close_30minus3  \
# dates
# 2022-01-14         26.881941          29.878337          31.164648
#
#             ema_5minus3  ema_15minus3  ema_30minus3  rsi_sma_7minus3  \
# dates
# 2022-01-14    26.781317     29.242168     31.939577        20.003771
#
#             rsi_sma_14minus3  rsi_sma_21minus3  bollinger_upper_5minus3  \
# dates
# 2022-01-14         23.002307         37.023824                30.272587
#
#             bollinger_lower_5minus3  bollinger_upper_10minus3  \
# dates
# 2022-01-14                23.491294                 34.279552
#
#             bollinger_lower_10minus3  bollinger_upper_20minus3  \
# dates
# 2022-01-14                  23.77931                  35.63917
#
#             bollinger_lower_20minus3  pricesminus4  total_volumesminus4  \
# dates
# 2022-01-14                 25.413655     26.675313         2.698768e+08
#
#             ma_close_5minus4  ma_close_15minus4  ma_close_30minus4  \
# dates
# 2022-01-14         27.804384          30.409629          31.522319
#
#             ema_5minus4  ema_15minus4  ema_30minus4  rsi_sma_7minus4  \
# dates
# 2022-01-14    27.740161     29.867673     32.427573        22.951151
#
#             rsi_sma_14minus4  rsi_sma_21minus4  bollinger_upper_5minus4  \
# dates
# 2022-01-14         32.847987         38.600534                30.950293
#
#             bollinger_lower_5minus4  bollinger_upper_10minus4  \
# dates
# 2022-01-14                24.658475                 33.949746
#
#             bollinger_lower_10minus4  bollinger_upper_20minus4  \
# dates
# 2022-01-14                 25.183073                  35.21867
#
#             bollinger_lower_20minus4  pricesminus5  total_volumesminus5  \
# dates
# 2022-01-14                 26.481183      25.87173         3.793455e+08
#
#             ma_close_5minus5  ma_close_15minus5  ma_close_30minus5  \
# dates
# 2022-01-14         28.918113          30.814693          31.817636
#
#             ema_5minus5  ema_15minus5  ema_30minus5  rsi_sma_7minus5  \
# dates
# 2022-01-14    28.272585     30.323725     32.824281        15.012834
#
#             rsi_sma_14minus5  rsi_sma_21minus5  bollinger_upper_5minus5  \
# dates
# 2022-01-14         30.034418         35.542407                33.622345
#
#             bollinger_lower_5minus5  bollinger_upper_10minus5  \
# dates
# 2022-01-14                24.213881                 33.909027
#
#             bollinger_lower_10minus5  bollinger_upper_20minus5  \
# dates
# 2022-01-14                 26.052288                 34.966073
#
#             bollinger_lower_20minus5  pricesminus6  total_volumesminus6  \
# dates
# 2022-01-14                  27.16185     27.748985         5.717897e+08
#
#             ma_close_5minus6  ma_close_15minus6  ma_close_30minus6  \
# dates
# 2022-01-14         29.943983          31.234491          32.065079
#
#             ema_5minus6  ema_15minus6  ema_30minus6  rsi_sma_7minus6  \
# dates
# 2022-01-14    29.473012     30.959724     33.303767        34.140983
#
#             rsi_sma_14minus6  rsi_sma_21minus6  bollinger_upper_5minus6  \
# dates
# 2022-01-14          36.13106         40.342688                33.397396
#
#             bollinger_lower_5minus6  bollinger_upper_10minus6  \
# dates
# 2022-01-14                 26.49057                 33.078443
#
#             bollinger_lower_10minus6  bollinger_upper_20minus6  \
# dates
# 2022-01-14                 27.739193                 34.409848
#
#             bollinger_lower_20minus6  pricesminus7  total_volumesminus7  \
# dates
# 2022-01-14                 28.311783     29.250045         4.600583e+08
#
#             ma_close_5minus7  ma_close_15minus7  ma_close_30minus7  \
# dates
# 2022-01-14         30.693983          31.590346          32.357214
#
#             ema_5minus7  ema_15minus7  ema_30minus7  rsi_sma_7minus7  \
# dates
# 2022-01-14    30.335025     31.418401     33.686856        38.666071
#
#             rsi_sma_14minus7  rsi_sma_21minus7  bollinger_upper_5minus7  \
# dates
# 2022-01-14         37.503135         41.296093                33.285038
#
#             bollinger_lower_5minus7  bollinger_upper_10minus7  \
# dates
# 2022-01-14                28.102927                   32.9405
#
#             bollinger_lower_10minus7  bollinger_upper_20minus7  \
# dates
# 2022-01-14                 28.745159                 34.140173
#
#             bollinger_lower_20minus7  pricesminus8  total_volumesminus8  \
# dates
# 2022-01-14                 29.035442     29.475846         7.931207e+08
#
#             ma_close_5minus8  ma_close_15minus8  ma_close_30minus8  \
# dates
# 2022-01-14         31.176922          31.741236          32.540246
#
#             ema_5minus8  ema_15minus8  ema_30minus8  rsi_sma_7minus8  \
# dates
# 2022-01-14    30.877515     31.728166     33.992843         45.39423
#
#             rsi_sma_14minus8  rsi_sma_21minus8  bollinger_upper_5minus8  \
# dates
# 2022-01-14         43.898975         39.664094                33.275692
#
#             bollinger_lower_5minus8  bollinger_upper_10minus8  \
# dates
# 2022-01-14                29.078152                 34.246662
#
#             bollinger_lower_10minus8  bollinger_upper_20minus8  \
# dates
# 2022-01-14                 28.506408                 34.017024
#
#             bollinger_lower_20minus8  pricesminus9  total_volumesminus9  \
# dates
# 2022-01-14                 29.410844     32.243958         6.206385e+08
#
#             ma_close_5minus9  ma_close_15minus9  ma_close_30minus9  \
# dates
# 2022-01-14         31.328435          31.865107          32.702529
#
#             ema_5minus9  ema_15minus9  ema_30minus9  rsi_sma_7minus9  \
# dates
# 2022-01-14    31.578349     32.049926      34.30436        51.187107
#
#             rsi_sma_14minus9  rsi_sma_21minus9  bollinger_upper_5minus9  \
# dates
# 2022-01-14         53.224857         49.164767                 32.84059
#
#             bollinger_lower_5minus9  bollinger_upper_10minus9  \
# dates
# 2022-01-14                29.816279                 34.371935
#
#             bollinger_lower_10minus9  bollinger_upper_20minus9  \
# dates
# 2022-01-14                 29.052567                 33.972352
#
#             bollinger_lower_20minus9  pricesminus10  total_volumesminus10  \
# dates
# 2022-01-14                 29.787199      31.001081          2.769506e+08
#
#             ma_close_5minus10  ma_close_15minus10  ma_close_30minus10  \
# dates
# 2022-01-14          31.043202           31.779244           32.780153
#
#             ema_5minus10  ema_15minus10  ema_30minus10  rsi_sma_7minus10  \
# dates
# 2022-01-14     31.245545      32.022207      34.446456         26.946477
#
#             rsi_sma_14minus10  rsi_sma_21minus10  bollinger_upper_5minus10  \
# dates
# 2022-01-14          50.170129          47.876946                 32.184427
#
#             bollinger_lower_5minus10  bollinger_upper_10minus10  \
# dates
# 2022-01-14                 29.901976                  34.486335
#
#             bollinger_lower_10minus10  bollinger_upper_20minus10  \
# dates
# 2022-01-14                  29.039632                  34.228776
#
#             bollinger_lower_20minus10  pricesminus11  total_volumesminus11  \
# dates
# 2022-01-14                  29.691963      31.498982          2.637016e+08
#
#             ma_close_5minus11  ma_close_15minus11  ma_close_30minus11  \
# dates
# 2022-01-14          30.873653           31.833093           32.952822
#
#             ema_5minus11  ema_15minus11  ema_30minus11  rsi_sma_7minus11  \
# dates
# 2022-01-14     31.367777      32.168083      34.684068          42.61644
#
#             rsi_sma_14minus11  rsi_sma_21minus11  bollinger_upper_5minus11  \
# dates
# 2022-01-14          48.860922          41.603678                 32.269627
#
#             bollinger_lower_5minus11  bollinger_upper_10minus11  \
# dates
# 2022-01-14                 29.477679                  34.557656
#
#             bollinger_lower_10minus11  bollinger_upper_20minus11  \
# dates
# 2022-01-14                  29.201834                  34.276146
#
#             bollinger_lower_20minus11  pricesminus12  total_volumesminus12  \
# dates
# 2022-01-14                  29.801793      31.664742          2.358454e+08
#
#             ma_close_5minus12  ma_close_15minus12  ma_close_30minus12  \
# dates
# 2022-01-14          30.991677           31.885749           33.368396
#
#             ema_5minus12  ema_15minus12  ema_30minus12  rsi_sma_7minus12  \
# dates
# 2022-01-14     31.302174      32.263668       34.90373           43.9298
#
#             rsi_sma_14minus12  rsi_sma_21minus12  bollinger_upper_5minus12  \
# dates
# 2022-01-14           47.75737          41.202014                 32.713703
#
#             bollinger_lower_5minus12  bollinger_upper_10minus12  \
# dates
# 2022-01-14                 29.269651                  34.802994
#
#             bollinger_lower_10minus12  bollinger_upper_20minus12  \
# dates
# 2022-01-14                  29.274061                  34.280378
#
#             bollinger_lower_20minus12  pricesminus13  total_volumesminus13  \
# dates
# 2022-01-14                  29.829365       30.23341          4.169757e+08
#
#             ma_close_5minus13  ma_close_15minus13  ma_close_30minus13  \
# dates
# 2022-01-14          31.576148           31.892937           33.895426
#
#             ema_5minus13  ema_15minus13  ema_30minus13  rsi_sma_7minus13  \
# dates
# 2022-01-14      31.12089      32.349229      35.127108         38.055263
#
#             rsi_sma_14minus13  rsi_sma_21minus13  bollinger_upper_5minus13  \
# dates
# 2022-01-14          44.079677          37.351497                 35.281735
#
#             bollinger_lower_5minus13  bollinger_upper_10minus13  \
# dates
# 2022-01-14                  27.87056                   34.79859
#
#             bollinger_lower_10minus13  bollinger_upper_20minus13  \
# dates
# 2022-01-14                  29.248197                   34.85663
#
#             bollinger_lower_20minus13  pricesminus14  total_volumesminus14  \
# dates
# 2022-01-14                  29.607881      30.817792          4.111008e+08
#
#             ma_close_5minus14  ma_close_15minus14  ma_close_30minus14  \
# dates
# 2022-01-14          32.096068           32.063556           34.489785
#
#             ema_5minus14  ema_15minus14  ema_30minus14  rsi_sma_7minus14  \
# dates
# 2022-01-14      31.56463      32.651489      35.464604         36.549571
#
#             rsi_sma_14minus14  rsi_sma_21minus14  bollinger_upper_5minus14  \
# dates
# 2022-01-14          42.650026          44.522378                 35.582693
#
#             bollinger_lower_5minus14  bollinger_upper_10minus14  \
# dates
# 2022-01-14                 28.609444                  34.670204
#
#             bollinger_lower_10minus14  bollinger_upper_20minus14  \
# dates
# 2022-01-14                  29.596683                    35.3503
#
#             bollinger_lower_20minus14
# dates
# 2022-01-14                  29.650248

# %%
# Test
test = df.iloc[len(df) - 1: len(df)]
print("Shape: " + str(test.shape))
test.tail(1)
# Out:
# Shape: (1, 256)
#               prices  total_volumes          y  ma_close_5  ma_close_15  \
# dates
# 2022-01-15  26.07813   3.360830e+08  26.100749   25.660432    28.264417
#
#             ma_close_30      ema_5     ema_15     ema_30  rsi_sma_7  \
# dates
# 2022-01-15    30.163986  26.041099  27.842453  30.516024  41.189002
#
#             rsi_sma_14  rsi_sma_21  bollinger_upper_5  bollinger_lower_5  \
# dates
# 2022-01-15   38.000572   38.018004          27.341749          23.979114
#
#             bollinger_upper_10  bollinger_lower_10  bollinger_upper_20  \
# dates
# 2022-01-15           30.012984           23.451832           35.100486
#
#             bollinger_lower_20  pricesminus1  total_volumesminus1  \
# dates
# 2022-01-15           23.344173      25.02043         3.138200e+08
#
#             ma_close_5minus1  ma_close_15minus1  ma_close_30minus1  \
# dates
# 2022-01-15         25.779868          28.580394          30.423243
#
#             ema_5minus1  ema_15minus1  ema_30minus1  rsi_sma_7minus1  \
# dates
# 2022-01-15    26.022584       28.0945     30.822085        28.692124
#
#             rsi_sma_14minus1  rsi_sma_21minus1  bollinger_upper_5minus1  \
# dates
# 2022-01-15         32.788127         34.043344                27.680135
#
#             bollinger_lower_5minus1  bollinger_upper_10minus1  \
# dates
# 2022-01-15                23.879601                 32.080082
#
#             bollinger_lower_10minus1  bollinger_upper_20minus1  \
# dates
# 2022-01-15                 22.617899                 35.440246
#
#             bollinger_lower_20minus1  pricesminus2  total_volumesminus2  \
# dates
# 2022-01-15                 23.671729     26.907742         3.247424e+08
#
#             ma_close_5minus2  ma_close_15minus2  ma_close_30minus2  \
# dates
# 2022-01-15         25.950129          28.922588          30.674998
#
#             ema_5minus2  ema_15minus2  ema_30minus2  rsi_sma_7minus2  \
# dates
# 2022-01-15    26.523661     28.533652     31.222199         34.46115
#
#             rsi_sma_14minus2  rsi_sma_21minus2  bollinger_upper_5minus2  \
# dates
# 2022-01-15         39.609647         40.774648                27.652411
#
#             bollinger_lower_5minus2  bollinger_upper_10minus2  \
# dates
# 2022-01-15                24.247846                 32.877731
#
#             bollinger_lower_10minus2  bollinger_upper_20minus2  \
# dates
# 2022-01-15                  23.01638                 35.498464
#
#             bollinger_lower_20minus2  pricesminus3  total_volumesminus3  \
# dates
# 2022-01-15                 24.328337     25.432227         2.859746e+08
#
#             ma_close_5minus3  ma_close_15minus3  ma_close_30minus3  \
# dates
# 2022-01-15         26.118377          29.268012          30.838641
#
#             ema_5minus3  ema_15minus3  ema_30minus3  rsi_sma_7minus3  \
# dates
# 2022-01-15     26.33162     28.765925     31.519748        14.359214
#
#             rsi_sma_14minus3  rsi_sma_21minus3  bollinger_upper_5minus3  \
# dates
# 2022-01-15         29.298914         37.531283                28.371172
#
#             bollinger_lower_5minus3  bollinger_upper_10minus3  \
# dates
# 2022-01-15                23.865582                 33.744888
#
#             bollinger_lower_10minus3  bollinger_upper_20minus3  \
# dates
# 2022-01-15                 23.067471                 35.790948
#
#             bollinger_lower_20minus3  pricesminus4  total_volumesminus4  \
# dates
# 2022-01-15                 24.653759      24.86363         4.994748e+08
#
#             ma_close_5minus4  ma_close_15minus4  ma_close_30minus4  \
# dates
# 2022-01-15         26.881941          29.878337          31.164648
#
#             ema_5minus4  ema_15minus4  ema_30minus4  rsi_sma_7minus4  \
# dates
# 2022-01-15    26.781317     29.242168     31.939577        20.003771
#
#             rsi_sma_14minus4  rsi_sma_21minus4  bollinger_upper_5minus4  \
# dates
# 2022-01-15         23.002307         37.023824                30.272587
#
#             bollinger_lower_5minus4  bollinger_upper_10minus4  \
# dates
# 2022-01-15                23.491294                 34.279552
#
#             bollinger_lower_10minus4  bollinger_upper_20minus4  \
# dates
# 2022-01-15                  23.77931                  35.63917
#
#             bollinger_lower_20minus4  pricesminus5  total_volumesminus5  \
# dates
# 2022-01-15                 25.413655     26.675313         2.698768e+08
#
#             ma_close_5minus5  ma_close_15minus5  ma_close_30minus5  \
# dates
# 2022-01-15         27.804384          30.409629          31.522319
#
#             ema_5minus5  ema_15minus5  ema_30minus5  rsi_sma_7minus5  \
# dates
# 2022-01-15    27.740161     29.867673     32.427573        22.951151
#
#             rsi_sma_14minus5  rsi_sma_21minus5  bollinger_upper_5minus5  \
# dates
# 2022-01-15         32.847987         38.600534                30.950293
#
#             bollinger_lower_5minus5  bollinger_upper_10minus5  \
# dates
# 2022-01-15                24.658475                 33.949746
#
#             bollinger_lower_10minus5  bollinger_upper_20minus5  \
# dates
# 2022-01-15                 25.183073                  35.21867
#
#             bollinger_lower_20minus5  pricesminus6  total_volumesminus6  \
# dates
# 2022-01-15                 26.481183      25.87173         3.793455e+08
#
#             ma_close_5minus6  ma_close_15minus6  ma_close_30minus6  \
# dates
# 2022-01-15         28.918113          30.814693          31.817636
#
#             ema_5minus6  ema_15minus6  ema_30minus6  rsi_sma_7minus6  \
# dates
# 2022-01-15    28.272585     30.323725     32.824281        15.012834
#
#             rsi_sma_14minus6  rsi_sma_21minus6  bollinger_upper_5minus6  \
# dates
# 2022-01-15         30.034418         35.542407                33.622345
#
#             bollinger_lower_5minus6  bollinger_upper_10minus6  \
# dates
# 2022-01-15                24.213881                 33.909027
#
#             bollinger_lower_10minus6  bollinger_upper_20minus6  \
# dates
# 2022-01-15                 26.052288                 34.966073
#
#             bollinger_lower_20minus6  pricesminus7  total_volumesminus7  \
# dates
# 2022-01-15                  27.16185     27.748985         5.717897e+08
#
#             ma_close_5minus7  ma_close_15minus7  ma_close_30minus7  \
# dates
# 2022-01-15         29.943983          31.234491          32.065079
#
#             ema_5minus7  ema_15minus7  ema_30minus7  rsi_sma_7minus7  \
# dates
# 2022-01-15    29.473012     30.959724     33.303767        34.140983
#
#             rsi_sma_14minus7  rsi_sma_21minus7  bollinger_upper_5minus7  \
# dates
# 2022-01-15          36.13106         40.342688                33.397396
#
#             bollinger_lower_5minus7  bollinger_upper_10minus7  \
# dates
# 2022-01-15                 26.49057                 33.078443
#
#             bollinger_lower_10minus7  bollinger_upper_20minus7  \
# dates
# 2022-01-15                 27.739193                 34.409848
#
#             bollinger_lower_20minus7  pricesminus8  total_volumesminus8  \
# dates
# 2022-01-15                 28.311783     29.250045         4.600583e+08
#
#             ma_close_5minus8  ma_close_15minus8  ma_close_30minus8  \
# dates
# 2022-01-15         30.693983          31.590346          32.357214
#
#             ema_5minus8  ema_15minus8  ema_30minus8  rsi_sma_7minus8  \
# dates
# 2022-01-15    30.335025     31.418401     33.686856        38.666071
#
#             rsi_sma_14minus8  rsi_sma_21minus8  bollinger_upper_5minus8  \
# dates
# 2022-01-15         37.503135         41.296093                33.285038
#
#             bollinger_lower_5minus8  bollinger_upper_10minus8  \
# dates
# 2022-01-15                28.102927                   32.9405
#
#             bollinger_lower_10minus8  bollinger_upper_20minus8  \
# dates
# 2022-01-15                 28.745159                 34.140173
#
#             bollinger_lower_20minus8  pricesminus9  total_volumesminus9  \
# dates
# 2022-01-15                 29.035442     29.475846         7.931207e+08
#
#             ma_close_5minus9  ma_close_15minus9  ma_close_30minus9  \
# dates
# 2022-01-15         31.176922          31.741236          32.540246
#
#             ema_5minus9  ema_15minus9  ema_30minus9  rsi_sma_7minus9  \
# dates
# 2022-01-15    30.877515     31.728166     33.992843         45.39423
#
#             rsi_sma_14minus9  rsi_sma_21minus9  bollinger_upper_5minus9  \
# dates
# 2022-01-15         43.898975         39.664094                33.275692
#
#             bollinger_lower_5minus9  bollinger_upper_10minus9  \
# dates
# 2022-01-15                29.078152                 34.246662
#
#             bollinger_lower_10minus9  bollinger_upper_20minus9  \
# dates
# 2022-01-15                 28.506408                 34.017024
#
#             bollinger_lower_20minus9  pricesminus10  total_volumesminus10  \
# dates
# 2022-01-15                 29.410844      32.243958          6.206385e+08
#
#             ma_close_5minus10  ma_close_15minus10  ma_close_30minus10  \
# dates
# 2022-01-15          31.328435           31.865107           32.702529
#
#             ema_5minus10  ema_15minus10  ema_30minus10  rsi_sma_7minus10  \
# dates
# 2022-01-15     31.578349      32.049926       34.30436         51.187107
#
#             rsi_sma_14minus10  rsi_sma_21minus10  bollinger_upper_5minus10  \
# dates
# 2022-01-15          53.224857          49.164767                  32.84059
#
#             bollinger_lower_5minus10  bollinger_upper_10minus10  \
# dates
# 2022-01-15                 29.816279                  34.371935
#
#             bollinger_lower_10minus10  bollinger_upper_20minus10  \
# dates
# 2022-01-15                  29.052567                  33.972352
#
#             bollinger_lower_20minus10  pricesminus11  total_volumesminus11  \
# dates
# 2022-01-15                  29.787199      31.001081          2.769506e+08
#
#             ma_close_5minus11  ma_close_15minus11  ma_close_30minus11  \
# dates
# 2022-01-15          31.043202           31.779244           32.780153
#
#             ema_5minus11  ema_15minus11  ema_30minus11  rsi_sma_7minus11  \
# dates
# 2022-01-15     31.245545      32.022207      34.446456         26.946477
#
#             rsi_sma_14minus11  rsi_sma_21minus11  bollinger_upper_5minus11  \
# dates
# 2022-01-15          50.170129          47.876946                 32.184427
#
#             bollinger_lower_5minus11  bollinger_upper_10minus11  \
# dates
# 2022-01-15                 29.901976                  34.486335
#
#             bollinger_lower_10minus11  bollinger_upper_20minus11  \
# dates
# 2022-01-15                  29.039632                  34.228776
#
#             bollinger_lower_20minus11  pricesminus12  total_volumesminus12  \
# dates
# 2022-01-15                  29.691963      31.498982          2.637016e+08
#
#             ma_close_5minus12  ma_close_15minus12  ma_close_30minus12  \
# dates
# 2022-01-15          30.873653           31.833093           32.952822
#
#             ema_5minus12  ema_15minus12  ema_30minus12  rsi_sma_7minus12  \
# dates
# 2022-01-15     31.367777      32.168083      34.684068          42.61644
#
#             rsi_sma_14minus12  rsi_sma_21minus12  bollinger_upper_5minus12  \
# dates
# 2022-01-15          48.860922          41.603678                 32.269627
#
#             bollinger_lower_5minus12  bollinger_upper_10minus12  \
# dates
# 2022-01-15                 29.477679                  34.557656
#
#             bollinger_lower_10minus12  bollinger_upper_20minus12  \
# dates
# 2022-01-15                  29.201834                  34.276146
#
#             bollinger_lower_20minus12  pricesminus13  total_volumesminus13  \
# dates
# 2022-01-15                  29.801793      31.664742          2.358454e+08
#
#             ma_close_5minus13  ma_close_15minus13  ma_close_30minus13  \
# dates
# 2022-01-15          30.991677           31.885749           33.368396
#
#             ema_5minus13  ema_15minus13  ema_30minus13  rsi_sma_7minus13  \
# dates
# 2022-01-15     31.302174      32.263668       34.90373           43.9298
#
#             rsi_sma_14minus13  rsi_sma_21minus13  bollinger_upper_5minus13  \
# dates
# 2022-01-15           47.75737          41.202014                 32.713703
#
#             bollinger_lower_5minus13  bollinger_upper_10minus13  \
# dates
# 2022-01-15                 29.269651                  34.802994
#
#             bollinger_lower_10minus13  bollinger_upper_20minus13  \
# dates
# 2022-01-15                  29.274061                  34.280378
#
#             bollinger_lower_20minus13  pricesminus14  total_volumesminus14  \
# dates
# 2022-01-15                  29.829365       30.23341          4.169757e+08
#
#             ma_close_5minus14  ma_close_15minus14  ma_close_30minus14  \
# dates
# 2022-01-15          31.576148           31.892937           33.895426
#
#             ema_5minus14  ema_15minus14  ema_30minus14  rsi_sma_7minus14  \
# dates
# 2022-01-15      31.12089      32.349229      35.127108         38.055263
#
#             rsi_sma_14minus14  rsi_sma_21minus14  bollinger_upper_5minus14  \
# dates
# 2022-01-15          44.079677          37.351497                 35.281735
#
#             bollinger_lower_5minus14  bollinger_upper_10minus14  \
# dates
# 2022-01-15                  27.87056                   34.79859
#
#             bollinger_lower_10minus14  bollinger_upper_20minus14  \
# dates
# 2022-01-15                  29.248197                   34.85663
#
#             bollinger_lower_20minus14
# dates
# 2022-01-15                  29.607881

# %%
# Crear pipeline
pipeline(train)

# %%
# Modelo
metrica = "MSE"
modelo = compare_models(sort = metrica, exclude = ["lar"] ,verbose = True)
# Out:
# IntProgress(value=0, description='Processing: ', max=89)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            22:46:45
# Status     . . . . . . . . . . . . . . . . . .    Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Regressor
# <style type="text/css">
# #T_823eb_ th {
#   text-align: left;
# }
# #T_823eb_row0_col0, #T_823eb_row0_col1, #T_823eb_row0_col2, #T_823eb_row0_col3, #T_823eb_row0_col4, #T_823eb_row0_col5, #T_823eb_row0_col6, #T_823eb_row0_col7, #T_823eb_row1_col0, #T_823eb_row1_col1, #T_823eb_row1_col2, #T_823eb_row1_col3, #T_823eb_row1_col4, #T_823eb_row1_col5, #T_823eb_row1_col6, #T_823eb_row1_col7, #T_823eb_row2_col0, #T_823eb_row2_col1, #T_823eb_row2_col2, #T_823eb_row2_col3, #T_823eb_row2_col4, #T_823eb_row2_col5, #T_823eb_row2_col6, #T_823eb_row2_col7, #T_823eb_row3_col0, #T_823eb_row3_col1, #T_823eb_row3_col2, #T_823eb_row3_col3, #T_823eb_row3_col4, #T_823eb_row3_col5, #T_823eb_row3_col6, #T_823eb_row3_col7, #T_823eb_row4_col0, #T_823eb_row4_col1, #T_823eb_row4_col2, #T_823eb_row4_col3, #T_823eb_row4_col4, #T_823eb_row4_col5, #T_823eb_row4_col6, #T_823eb_row4_col7, #T_823eb_row5_col0, #T_823eb_row5_col1, #T_823eb_row5_col2, #T_823eb_row5_col3, #T_823eb_row5_col4, #T_823eb_row5_col5, #T_823eb_row5_col6, #T_823eb_row5_col7, #T_823eb_row6_col0, #T_823eb_row6_col1, #T_823eb_row6_col2, #T_823eb_row6_col3, #T_823eb_row6_col4, #T_823eb_row6_col5, #T_823eb_row6_col6, #T_823eb_row6_col7, #T_823eb_row7_col0, #T_823eb_row7_col1, #T_823eb_row7_col2, #T_823eb_row7_col3, #T_823eb_row7_col4, #T_823eb_row7_col5, #T_823eb_row7_col6, #T_823eb_row7_col7, #T_823eb_row8_col0, #T_823eb_row8_col1, #T_823eb_row8_col2, #T_823eb_row8_col3, #T_823eb_row8_col4, #T_823eb_row8_col5, #T_823eb_row8_col6, #T_823eb_row8_col7, #T_823eb_row9_col0, #T_823eb_row9_col1, #T_823eb_row9_col2, #T_823eb_row9_col3, #T_823eb_row9_col4, #T_823eb_row9_col5, #T_823eb_row9_col6, #T_823eb_row9_col7, #T_823eb_row10_col0, #T_823eb_row10_col1, #T_823eb_row10_col2, #T_823eb_row10_col3, #T_823eb_row10_col4, #T_823eb_row10_col5, #T_823eb_row10_col6, #T_823eb_row10_col7, #T_823eb_row11_col0, #T_823eb_row11_col1, #T_823eb_row11_col2, #T_823eb_row11_col3, #T_823eb_row11_col4, #T_823eb_row11_col5, #T_823eb_row11_col6, #T_823eb_row11_col7, #T_823eb_row12_col0, #T_823eb_row12_col1, #T_823eb_row12_col2, #T_823eb_row12_col3, #T_823eb_row12_col4, #T_823eb_row12_col5, #T_823eb_row12_col6, #T_823eb_row12_col7, #T_823eb_row13_col0, #T_823eb_row13_col1, #T_823eb_row13_col2, #T_823eb_row13_col3, #T_823eb_row13_col4, #T_823eb_row13_col5, #T_823eb_row13_col6, #T_823eb_row13_col7, #T_823eb_row14_col0, #T_823eb_row14_col1, #T_823eb_row14_col2, #T_823eb_row14_col3, #T_823eb_row14_col4, #T_823eb_row14_col5, #T_823eb_row14_col6, #T_823eb_row14_col7, #T_823eb_row15_col0, #T_823eb_row15_col1, #T_823eb_row15_col2, #T_823eb_row15_col3, #T_823eb_row15_col4, #T_823eb_row15_col5, #T_823eb_row15_col6, #T_823eb_row15_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_823eb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_823eb_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_823eb_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_823eb_row0_col1" class="data row0 col1" >2.2733</td>
#       <td id="T_823eb_row0_col2" class="data row0 col2" >10.3947</td>
#       <td id="T_823eb_row0_col3" class="data row0 col3" >3.1270</td>
#       <td id="T_823eb_row0_col4" class="data row0 col4" >0.9266</td>
#       <td id="T_823eb_row0_col5" class="data row0 col5" >0.0580</td>
#       <td id="T_823eb_row0_col6" class="data row0 col6" >0.0449</td>
#       <td id="T_823eb_row0_col7" class="data row0 col7" >0.0820</td>
#     </tr>
#     <tr>
#       <th id="T_823eb_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_823eb_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_823eb_row1_col1" class="data row1 col1" >2.1703</td>
#       <td id="T_823eb_row1_col2" class="data row1 col2" >10.8370</td>
#       <td id="T_823eb_row1_col3" class="data row1 col3" >3.1152</td>
#       <td id="T_823eb_row1_col4" class="data row1 col4" >0.9253</td>
#       <td id="T_823eb_row1_col5" class="data row1 col5" >0.0566</td>
#       <td id="T_823eb_row1_col6" class="data row1 col6" >0.0426</td>
#       <td id="T_823eb_row1_col7" class="data row1 col7" >0.1390</td>
#     </tr>
#     <tr>
#       <th id="T_823eb_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_823eb_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_823eb_row2_col1" class="data row2 col1" >2.1470</td>
#       <td id="T_823eb_row2_col2" class="data row2 col2" >10.9445</td>
#       <td id="T_823eb_row2_col3" class="data row2 col3" >3.1491</td>
#       <td id="T_823eb_row2_col4" class="data row2 col4" >0.9253</td>
#       <td id="T_823eb_row2_col5" class="data row2 col5" >0.0573</td>
#       <td id="T_823eb_row2_col6" class="data row2 col6" >0.0419</td>
#       <td id="T_823eb_row2_col7" class="data row2 col7" >0.1810</td>
#     </tr>
#     <tr>
#       <th id="T_823eb_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_823eb_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_823eb_row3_col1" class="data row3 col1" >2.2938</td>
#       <td id="T_823eb_row3_col2" class="data row3 col2" >11.9371</td>
#       <td id="T_823eb_row3_col3" class="data row3 col3" >3.2827</td>
#       <td id="T_823eb_row3_col4" class="data row3 col4" >0.9226</td>
#       <td id="T_823eb_row3_col5" class="data row3 col5" >0.0629</td>
#       <td id="T_823eb_row3_col6" class="data row3 col6" >0.0476</td>
#       <td id="T_823eb_row3_col7" class="data row3 col7" >0.1470</td>
#     </tr>
#     <tr>
#       <th id="T_823eb_level0_row4" class="row_heading level0 row4" >omp</th>
#       <td id="T_823eb_row4_col0" class="data row4 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_823eb_row4_col1" class="data row4 col1" >2.5502</td>
#       <td id="T_823eb_row4_col2" class="data row4 col2" >13.3639</td>
#       <td id="T_823eb_row4_col3" class="data row4 col3" >3.4527</td>
#       <td id="T_823eb_row4_col4" class="data row4 col4" >0.9137</td>
#       <td id="T_823eb_row4_col5" class="data row4 col5" >0.0640</td>
#       <td id="T_823eb_row4_col6" class="data row4 col6" >0.0503</td>
#       <td id="T_823eb_row4_col7" class="data row4 col7" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_823eb_level0_row5" class="row_heading level0 row5" >br</th>
#       <td id="T_823eb_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_823eb_row5_col1" class="data row5 col1" >2.5936</td>
#       <td id="T_823eb_row5_col2" class="data row5 col2" >14.3520</td>
#       <td id="T_823eb_row5_col3" class="data row5 col3" >3.6334</td>
#       <td id="T_823eb_row5_col4" class="data row5 col4" >0.9051</td>
#       <td id="T_823eb_row5_col5" class="data row5 col5" >0.0707</td>
#       <td id="T_823eb_row5_col6" class="data row5 col6" >0.0530</td>
#       <td id="T_823eb_row5_col7" class="data row5 col7" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_823eb_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_823eb_row6_col0" class="data row6 col0" >AdaBoost Regressor</td>
#       <td id="T_823eb_row6_col1" class="data row6 col1" >2.7045</td>
#       <td id="T_823eb_row6_col2" class="data row6 col2" >14.7908</td>
#       <td id="T_823eb_row6_col3" class="data row6 col3" >3.7155</td>
#       <td id="T_823eb_row6_col4" class="data row6 col4" >0.8996</td>
#       <td id="T_823eb_row6_col5" class="data row6 col5" >0.0684</td>
#       <td id="T_823eb_row6_col6" class="data row6 col6" >0.0538</td>
#       <td id="T_823eb_row6_col7" class="data row6 col7" >0.0410</td>
#     </tr>
#     <tr>
#       <th id="T_823eb_level0_row7" class="row_heading level0 row7" >ridge</th>
#       <td id="T_823eb_r

# %%
modelo = tune_model(modelo, search_algorithm = "tpe", search_library = "optuna", optimize = metrica, n_iter = 10,
                    tuner_verbose = False, choose_better = True, verbose = True )

# %%
final_modelo = finalize_model(modelo)

# %%
prediccion = predict_model(final_modelo, data = test)

# %%
import telepot

bot_token = '1653124784:AAFpL0qlC_ybadcbFX6jKagauRFpiFpSf1E'
chatID = '-1001701018194'

bot = telepot.Bot(bot_token)

# %%
from datetime import datetime

# %%
mensaje = "BTC : " + str(prediccion["Label"][0].round(2)) + " EUR at " + str(datetime.today().strftime('%d-%m-%Y'))
print(mensaje)

# %%
bot.sendMessage(chatID, mensaje)
