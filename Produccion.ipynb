# %%
# %reset -f
import sys
print("Python version")
print(sys.version)
# Out:
# Python version
# 3.7.9 (tags/v3.7.9:13c94747c7, Aug 17 2020, 18:58:18) [MSC v.1900 64 bit (AMD64)]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

import warnings
warnings.filterwarnings('ignore')

# %%
#Coingecko api
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %%
import time
import datetime

def edit_prices_dict(d): 
    df=pd.DataFrame(d)
    #Saving dates
    dates=df['prices'].map(lambda x: x[0])  
    #Filtering the values without dates
    df=df.applymap(lambda x: x[1])
    df['dates']=dates 
    df["dates"] = pd.to_datetime(df['dates'], unit='ms')
    df.index = df["dates"]
    df=df[['prices','total_volumes']]
    return df

# %%
#dd/mm/yyyy
from_date = "01/01/2021"
to_date = "21/12/2021"
from_unix = time.mktime(datetime.datetime.strptime(from_date, "%d/%m/%Y").timetuple())
to_unix = time.mktime(datetime.datetime.strptime(to_date, "%d/%m/%Y").timetuple())

token = "bitcoin"; vs_currency = "usd"

response=cg.get_coin_market_chart_range_by_id(id = token, vs_currency = vs_currency, from_timestamp = from_unix, to_timestamp = to_unix)

# %%
df = edit_prices_dict(response)
print(df.shape)
df.tail()
# Out:
# (341, 2)
#                   prices  total_volumes
# dates
# 2021-12-03  56508.268054   3.629634e+10
# 2021-12-04  53785.967172   3.952711e+10
# 2021-12-05  49161.990710   5.594141e+10
# 2021-12-06  49268.469891   3.282657e+10
# 2021-12-07  50461.576837   3.612602e+10

# %%
# Esto hay que hacerlo pues es con la info de hoy predecir mañana
lag_days = 1
df["y"] = df["prices"].shift(-1 * lag_days)
df.tail(5)
# Out:
#                   prices  total_volumes             y
# dates
# 2021-12-03  56508.268054   3.629634e+10  53785.967172
# 2021-12-04  53785.967172   3.952711e+10  49161.990710
# 2021-12-05  49161.990710   5.594141e+10  49268.469891
# 2021-12-06  49268.469891   3.282657e+10  50461.576837
# 2021-12-07  50461.576837   3.612602e+10           NaN

# %%
#https://towardsdatascience.com/building-a-comprehensive-set-of-technical-indicators-in-python-for-quantitative-trading-8d98751b5fb
# MovingAverage
values_ma = [5,15,30]

for i in values_ma:
    df["ma_close_" + str(i)] = df["prices"].rolling(window=i).mean()

# ExponentialMovingWindow
values_ema = [5,15,30]

for i in values_ema:
    df["ema_" + str(i)] = df["prices"].ewm(span = i, adjust = False).mean()
    
# RSI https://stackoverflow.com/questions/20526414/relative-strength-index-in-python-pandas
values_rsi = [7,14,21]
close = df['prices']

# Get the difference in price from previous step
delta = close.diff()

# Make the positive gains (up) and negative gains (down) Series
up, down = delta.copy(), delta.copy()
up[up < 0] = 0
down[down > 0] = 0

for i in values_rsi:
    # Calculate the EWMA
    #roll_up1 = up.ewm(span=i).mean()
    #roll_down1 = down.abs().ewm(span=i).mean()

    ## Calculate the RSI based on EWMA
    #RS1 = roll_up1 / roll_down1
    #RSI1 = 100.0 - (100.0 / (1.0 + RS1))

    # Calculate the SMA
    roll_up2 = up.rolling(i).mean()
    roll_down2 = down.abs().rolling(i).mean()

    # Calculate the RSI based on SMA
    RS2 = roll_up2 / roll_down2
    RSI2 = 100.0 - (100.0 / (1.0 + RS2))
    
    #df["rsi_ewma_" + str(i)] = RSI1.values
    df["rsi_sma_" + str(i)]  = RSI2.values
    
# BollingerBand
values_bollinger = [5,10,20]
for i in values_bollinger:
    df['bollinger_upper_' + str(i)] = df['prices'].rolling(window=i).mean() + (df['prices'].rolling(window=i).std()  * 2)
    df['bollinger_lower_' + str(i)] = df['prices'].rolling(window=i).mean() - (df['prices'].rolling(window=i).std()  * 2)

# %%
minus = 15 # Es el lag del pasado cuanto pillamos

# %%
all_columns = list(df.columns)
keep_columns = [item for item in all_columns if item not in "y"]
print(keep_columns)
# Out:
# ['prices', 'total_volumes', 'ma_close_5', 'ma_close_15', 'ma_close_30', 'ema_5', 'ema_15', 'ema_30', 'rsi_sma_7', 'rsi_sma_14', 'rsi_sma_21', 'bollinger_upper_5', 'bollinger_lower_5', 'bollinger_upper_10', 'bollinger_lower_10', 'bollinger_upper_20', 'bollinger_lower_20']

# %%
list_shift = list(range(1, minus))

for i in list_shift:
    for j in keep_columns:
        df[str(j) + "minus" + str(i)] = df[str(j)].shift(i)

# %%
print("Shape: " + str(df.shape))
df.dropna(inplace = True)
print("Shape: " + str(df.shape))
# Out:
# Shape: (341, 256)
# Shape: (297, 256)

# %%
df.tail(2)
# Out:
#                   prices  total_volumes             y    ma_close_5  \
# dates
# 2021-12-05  49161.990710   5.594141e+10  49268.469891  54727.375681
# 2021-12-06  49268.469891   3.282657e+10  50461.576837  53178.813564
#
#              ma_close_15   ma_close_30         ema_5        ema_15  \
# dates
# 2021-12-05  56435.925442  59753.464608  53605.222889  56297.338312
# 2021-12-06  55714.962657  59354.167440  52159.638556  55418.729759
#
#                   ema_30  rsi_sma_7  rsi_sma_14  rsi_sma_21  \
# dates
# 2021-12-05  57905.964223  28.197488   28.504040   29.850475
# 2021-12-06  57348.706524   9.008569   29.908276   28.203599
#
#             bollinger_upper_5  bollinger_lower_5  bollinger_upper_10  \
# dates
# 2021-12-05       61525.235977       47929.515385        61290.776455
# 2021-12-06       60847.197538       45510.429590        61058.080544
#
#             bollinger_lower_10  bollinger_upper_20  bollinger_lower_20  \
# dates
# 2021-12-05        49905.694907        63509.165535        51187.985795
# 2021-12-06        48212.515399        62963.866056        50266.748720
#
#             pricesminus1  total_volumesminus1  ma_close_5minus1  \
# dates
# 2021-12-05  53785.967172         3.952711e+10      56464.732246
# 2021-12-06  49161.990710         5.594141e+10      54727.375681
#
#             ma_close_15minus1  ma_close_30minus1   ema_5minus1  ema_15minus1  \
# dates
# 2021-12-05       57055.743096       60168.123037  55826.838978  57316.673683
# 2021-12-06       56435.925442       59753.464608  53605.222889  56297.338312
#
#             ema_30minus1  rsi_sma_7minus1  rsi_sma_14minus1  rsi_sma_21minus1  \
# dates
# 2021-12-05  58508.996879        49.751037         39.569458         34.372794
# 2021-12-06  57905.964223        28.197488         28.504040         29.850475
#
#             bollinger_upper_5minus1  bollinger_lower_5minus1  \
# dates
# 2021-12-05             59609.327629             53320.136863
# 2021-12-06             61525.235977             47929.515385
#
#             bollinger_upper_10minus1  bollinger_lower_10minus1  \
# dates
# 2021-12-05              59903.463566              52900.246423
# 2021-12-06              61290.776455              49905.694907
#
#             bollinger_upper_20minus1  bollinger_lower_20minus1  pricesminus2  \
# dates
# 2021-12-05              64129.992223              52215.857816  56508.268054
# 2021-12-06              63509.165535              51187.985795  53785.967172
#
#             total_volumesminus2  ma_close_5minus2  ma_close_15minus2  \
# dates
# 2021-12-05         3.629634e+10      57155.071039       57269.166774
# 2021-12-06         3.952711e+10      56464.732246       57055.743096
#
#             ma_close_30minus2   ema_5minus2  ema_15minus2  ema_30minus2  \
# dates
# 2021-12-05       60479.622210  56847.274881  57821.060328  58834.723066
# 2021-12-06       60168.123037  55826.838978  57316.673683  58508.996879
#
#             rsi_sma_7minus2  rsi_sma_14minus2  rsi_sma_21minus2  \
# dates
# 2021-12-05        38.883325         48.867568         36.687047
# 2021-12-06        49.751037         39.569458         34.372794
#
#             bollinger_upper_5minus2  bollinger_lower_5minus2  \
# dates
# 2021-12-05             58118.024115             56192.117964
# 2021-12-06             59609.327629             53320.136863
#
#             bollinger_upper_10minus2  bollinger_lower_10minus2  \
# dates
# 2021-12-05              59852.374375              53743.900815
# 2021-12-06              59903.463566              52900.246423
#
#             bollinger_upper_20minus2  bollinger_lower_20minus2  pricesminus3  \
# dates
# 2021-12-05              64965.686899              52467.599958  57169.371994
# 2021-12-06              64129.992223              52215.857816  56508.268054
#
#             total_volumesminus3  ma_close_5minus3  ma_close_15minus3  \
# dates
# 2021-12
# dates
# 2021-12-06  57905.964223        28.197488          28.50404         29.850475
#
#             bollinger_upper_5minus1  bollinger_lower_5minus1  \
# dates
# 2021-12-06             61525.235977             47929.515385
#
#             bollinger_upper_10minus1  bollinger_lower_10minus1  \
# dates
# 2021-12-06              61290.776455              49905.694907
#
#             bollinger_upper_20minus1  bollinger_lower_20minus1  pricesminus2  \
# dates
# 2021-12-06              63509.165535              51187.985795  53785.967172
#
#             total_volumesminus2  ma_close_5minus2  ma_close_15minus2  \
# dates
# 2021-12-06         3.952711e+10      56464.732246       57055.743096
#
#             ma_close_30minus2   ema_5minus2  ema_15minus2  ema_30minus2  \
# dates
# 2021-12-06       60168.123037  55826.838978  57316.673683  58508.996879
#
#             rsi_sma_7minus2  rsi_sma_14minus2  rsi_sma_21minus2  \
# dates
# 2021-12-06        49.751037         39.569458         34.372794
#
#             bollinger_upper_5minus2  bollinger_lower_5minus2  \
# dates
# 2021-12-06             59609.327629             53320.136863
#
#             bollinger_upper_10minus2  bollinger_lower_10minus2  \
# dates
# 2021-12-06              59903.463566              52900.246423
#
#             bollinger_upper_20minus2  bollinger_lower_20minus2  pricesminus3  \
# dates
# 2021-12-06              64129.992223              52215.857816  56508.268054
#
#             total_volumesminus3  ma_close_5minus3  ma_close_15minus3  \
# dates
# 2021-12-06         3.629634e+10      57155.071039       57269.166774
#
#             ma_close_30minus3   ema_5minus3  ema_15minus3  ema_30minus3  \
# dates
# 2021-12-06        60479.62221  56847.274881  57821.060328  58834.723066
#
#             rsi_sma_7minus3  rsi_sma_14minus3  rsi_sma_21minus3  \
# dates
# 2021-12-06        38.883325         48.867568         36.687047
#
#             bollinger_upper_5minus3  bollinger_lower_5minus3  \
# dates
# 2021-12-06             58118.024115             56192.117964
#
#             bollinger_upper_10minus3  bollinger_lower_10minus3  \
# dates
# 2021-12-06              59852.374375              53743.900815
#
#             bollinger_upper_20minus3  bollinger_lower_20minus3  pricesminus4  \
# dates
# 2021-12-06              64965.686899              52467.599958  57169.371994
#
#             total_volumesminus4  ma_close_5minus4  ma_close_15minus4  \
# dates
# 2021-12-06         4.938307e+10      56760.098205       57542.192628
#
#             ma_close_30minus4   ema_5minus4  ema_15minus4  ema_30minus4  \
# dates
# 2021-12-06       60704.253573  57016.778295  58008.602081  58995.168239
#
#             rsi_sma_7minus4  rsi_sma_14minus4  rsi_sma_21minus4  \
# dates
# 2021-12-06        49.877774         42.876941         37.396801
#
#             bollinger_upper_5minus4  bollinger_lower_5minus4  \
# dates
# 2021-12-06             59329.542796             54190.653614
#
#             bollinger_upper_10minus4  bollinger_lower_10minus4  \
# dates
# 2021-12-06              59846.313715              53725.679234
#
#             bollinger_upper_20minus4  bollinger_lower_20minus4  pricesminus5  \
# dates
# 2021-12-06              65764.143304              52461.521542  57011.280474
#
#             total_volumesminus5  ma_close_5minus5  ma_close_15minus5  \
# dates
# 2021-12-06         3.572304e+10      56091.782379       57760.805329
#
#             ma_close_30minus5   ema_5minus5  ema_15minus5  ema_30minus5  \
# dates
# 2021-12-06       60836.002213  56940.481446  58128.492094  59121.085222
#
#             rsi_sma_7minus5  rsi_sma_14minus5  rsi_sma_21minus5  \
# dates
# 2021-12-06        46.972146         42.869836         34.753644
#
#             bollinger_upper_5minus5  bollinger_lower_5minus5  \
# dates
# 2021-12-06             59669.452691             52514.112067
#
#             bollinger_upper_10minus5  bollinger_lower_10minus5  \
# dates
# 2021-12-06              60387.448383              53578.626023
#
#             bollinger_upper_20minus5  bollinger_lower_20minus5  pricesminus6  \
# dates
# 2021-12-06              66583.414079              52425.878084  57848.773537
#
#             total_volumesminus6  ma_close_5minus6  ma_close_15minus6  \
# dates
# 2021-12-06         3.098520e+10      56469.095681       58222.308994
#
#             ma_close_30minus6   ema_5minus6  ema_15minus6  ema_30minus6  \
# dates
# 2021-12-06        60984.68848  56905.081931  58288.093754  59266.588997
#
#             rsi_sma_7minus6  rsi_sma_14minus6  rsi_sma_21minus6  \
# dates
# 2021-12-06        55.754108         38.626727         35.140478
#
#             bollinger_upper_5minus6  bollinger_lower_5minus6  \
# dates
# 2021-12-06             60841.328525             52096.862837
#
#             bollinger_upper_10minus6  bollinger_lower_10minus6  \
# dates
# 2021-12-06              61219.716382              53360.684263
#
#             bollinger_upper_20minus6  bollinger_lower_20minus6  pricesminus7  \
# dates
# 2021-12-06              67297.518304              52516.751253  57237.661137
#
#             total_volumesminus7  ma_close_5minus7  ma_close_15minus7  \
# dates
# 2021-12-06         2.765946e+10      56338.977743       58742.322611
#
#             ma_close_30minus7   ema_5minus7  ema_15minus7  ema_30minus7  \
# dates
# 2021-12-06       61117.637929  56433.236129  58350.853784  59364.369374
#
#             rsi_sma_7minus7  rsi_sma_14minus7  rsi_sma_21minus7  \
# dates
# 2021-12-06        43.593428         34.901938         41.945316
#
#             bollinger_upper_5minus7  bollinger_lower_5minus7  \
# dates
# 2021-12-06             60541.337225             52136.618261
#
#             bollinger_upper_10minus7  bollinger_lower_10minus7  \
# dates
# 2021-12-06              61337.886437              53364.610604
#
#             bollinger_upper_20minus7  bollinger_lower_20minus7  pricesminus8  \
# dates
# 2021-12-06              68362.331822              52381.597874  54533.403882
#
#             total_volumesminus8  ma_close_5minus8  ma_close_15minus8  \
# dates
# 2021-12-06         2.825685e+10       56441.20415       59237.167558
#
#             ma_close_30minus8   ema_5minus8  ema_15minus8  ema_30minus8  \
# dates
# 2021-12-06       61285.822492  56031.023624  58509.881305  59511.038907
#
#             rsi_sma_7minus8  rsi_sma_14minus8  rsi_sma_21minus8  \
# dates
# 2021-12-06        28.792655         30.629437         39.963147
#
#             bollinger_upper_5minus8  bollinger_lower_5minus8  \
# dates
# 2021-12-06              60775.66164              52106.74666
#
#             bollinger_upper_10minus8  bollinger_lower_10minus8  \
# dates
# 2021-12-06              61319.161614              53333.267667
#
#             bollinger_upper_20minus8  bollinger_lower_20minus8  pricesminus9  \
# dates
# 2021-12-06              69358.190632              52423.674505  53827.792865
#
#             total_volumesminus9  ma_close_5minus9  ma_close_15minus9  \
# dates
# 2021-12-06         4.132581e+10      56811.894744       59897.077163
#
#             ma_close_30minus9   ema_5minus9  ema_15minus9  ema_30minus9  \
# dates
# 2021-12-06       61493.627558  56779.833495  59077.949509  59854.324081
#
#             rsi_sma_7minus9  rsi_sma_14minus9  rsi_sma_21minus9  \
# dates
# 2021-12-06        33.461394          29.33915         39.465977
#
#             bollinger_upper_5minus9  bollinger_lower_5minus9  \
# dates
# 2021-12-06             60615.013979             53008.775509
#
#             bollinger_upper_10minus9  bollinger_lower_10minus9  \
# dates
# 2021-12-06              61884.621628               53981.85805
#
#             bollinger_upper_20minus9  bollinger_lower_20minus9  pricesminus10  \
# dates
# 2021-12-06              69289.402915              53354.444853   58897.846983
#
#             total_volumesminus10  ma_close_5minus10  ma_close_15minus10  \
# dates
# 2021-12-06          3.372110e+10       57874.292027        60642.267316
#
#             ma_close_30minus10  ema_5minus10  ema_15minus10  ema_30minus10  \
# dates
# 2021-12-06        61654.067845   58255.85381   59827.971886   60269.946924
#
#             rsi_sma_7minus10  rsi_sma_14minus10  rsi_sma_21minus10  \
# dates
# 2021-12-06         59.181813          35.571827          45.567613
#
#             bollinger_upper_5minus10  bollinger_lower_5minus10  \
# dates
# 2021-12-06              60183.936668              55564.647387
#
#             bollinger_upper_10minus10  bollinger_lower_10minus10  \
# dates
# 2021-12-06               61593.011089               55597.622519
#
#             bollinger_upper_20minus10  bollinger_lower_20minus10  \
# dates
# 2021-12-06               68857.512479               54569.691869
#
#             pricesminus11  total_volumesminus11  ma_close_5minus11  \
# dates
# 2021-12-06   57198.183846          3.169537e+10       58111.304964
#
#             ma_close_15minus11  ma_close_30minus11  ema_5minus11  \
# dates
# 2021-12-06         61053.14781        61710.945909  57934.857224
#
#             ema_15minus11  ema_30minus11  rsi_sma_7minus11  rsi_sma_14minus11  \
# dates
# 2021-12-06   59960.846873   60364.574506         36.179678          29.861481
#
#             rsi_sma_21minus11  bollinger_upper_5minus11  \
# dates
# 2021-12-06          40.220013              61091.895288
#
#             bollinger_lower_5minus11  bollinger_upper_10minus11  \
# dates
# 2021-12-06              55130.714641               63624.940326
#
#             bollinger_lower_10minus11  bollinger_upper_20minus11  \
# dates
# 2021-12-06               54572.890974               68856.315886
#
#             bollinger_lower_20minus11  pricesminus12  total_volumesminus12  \
# dates
# 2021-12-06               54805.842258   57748.793174          3.642119e+10
#
#             ma_close_5minus12  ma_close_15minus12  ma_close_30minus12  \
# dates
# 2021-12-06       58363.519298        61716.293883        61911.946908
#
#             ema_5minus12  ema_15minus12  ema_30minus12  rsi_sma_7minus12  \
# dates
# 2021-12-06  58303.193913   60355.513019   60582.946276         38.680219
#
#             rsi_sma_14minus12  rsi_sma_21minus12  bollinger_upper_5minus12  \
# dates
# 2021-12-06          27.686349          40.804333               61165.86434
#
#             bollinger_lower_5minus12  bollinger_upper_10minus12  \
# dates
# 2021-12-06              55561.174256                65840.88554
#
#             bollinger_lower_10minus12  bollinger_upper_20minus12  \
# dates
# 2021-12-06               54047.104549               68732.741026
#
#             bollinger_lower_20minus12  pricesminus13  total_volumesminus13  \
# dates
# 2021-12-06                55369.77309   56386.856853          3.400147e+10
#
#             ma_close_5minus13  ma_close_15minus13  ma_close_30minus13  \
# dates
# 2021-12-06       58211.225131        62374.175374        62026.092682
#
#             ema_5minus13  ema_15minus13  ema_30minus13  rsi_sma_7minus13  \
# dates
# 2021-12-06  58580.394282   60727.901569    60778.40511         23.139259
#
#             rsi_sma_14minus13  rsi_sma_21minus13  bollinger_upper_5minus13  \
# dates
# 2021-12-06           22.15486          42.278309              61253.132433
#
#             bollinger_lower_5minus13  bollinger_upper_10minus13  \
# dates
# 2021-12-06               55169.31783               66990.828351
#
#             bollinger_lower_10minus13  bollinger_upper_20minus13  \
# dates
# 2021-12-06               54279.470173               68698.893162
#
#             bollinger_lower_20minus13  pricesminus14  total_volumesminus14  \
# dates
# 2021-12-06               55941.835872    59139.77928          2.574343e+10
#
#             ma_close_5minus14  ma_close_15minus14  ma_close_30minus14  \
# dates
# 2021-12-06       59054.584934         62825.26693        62198.935468
#
#             ema_5minus14  ema_15minus14  ema_30minus14  rsi_sma_7minus14  \
# dates
# 2021-12-06  59677.162996   61348.050814   61081.270507         24.984948
#
#             rsi_sma_14minus14  rsi_sma_21minus14  bollinger_upper_5minus14  \
# dates
# 2021-12-06          40.826921          45.873479              61899.286405
#
#             bollinger_lower_5minus14  bollinger_upper_10minus14  \
# dates
# 2021-12-06              56209.883463                67431.66002
#
#             bollinger_lower_10minus14  bollinger_upper_20minus14  \
# dates
# 2021-12-06               55447.676724               68404.389504
#
#             bollinger_lower_20minus14
# dates
# 2021-12-06               56922.374741

# %%
# Crear pipeline
pipeline(train)

# %%
# Modelo
metrica = "MSE"
modelo = compare_models(sort = metrica, exclude = ["lar"] ,verbose = True)
# Out:
# <style type="text/css">
# #T_f73b8_ th {
#   text-align: left;
# }
# #T_f73b8_row0_col0, #T_f73b8_row1_col0, #T_f73b8_row1_col1, #T_f73b8_row1_col2, #T_f73b8_row1_col3, #T_f73b8_row1_col4, #T_f73b8_row1_col5, #T_f73b8_row1_col6, #T_f73b8_row2_col0, #T_f73b8_row2_col1, #T_f73b8_row2_col2, #T_f73b8_row2_col3, #T_f73b8_row2_col4, #T_f73b8_row2_col5, #T_f73b8_row2_col6, #T_f73b8_row3_col0, #T_f73b8_row3_col1, #T_f73b8_row3_col2, #T_f73b8_row3_col3, #T_f73b8_row3_col4, #T_f73b8_row3_col5, #T_f73b8_row3_col6, #T_f73b8_row4_col0, #T_f73b8_row4_col1, #T_f73b8_row4_col2, #T_f73b8_row4_col3, #T_f73b8_row4_col4, #T_f73b8_row4_col5, #T_f73b8_row4_col6, #T_f73b8_row5_col0, #T_f73b8_row5_col1, #T_f73b8_row5_col2, #T_f73b8_row5_col3, #T_f73b8_row5_col4, #T_f73b8_row5_col5, #T_f73b8_row5_col6, #T_f73b8_row6_col0, #T_f73b8_row6_col1, #T_f73b8_row6_col2, #T_f73b8_row6_col3, #T_f73b8_row6_col4, #T_f73b8_row6_col5, #T_f73b8_row6_col6, #T_f73b8_row7_col0, #T_f73b
>0.1310</td>
#     </tr>
#     <tr>
#       <th id="T_f73b8_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_f73b8_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_f73b8_row1_col1" class="data row1 col1" >1567.8637</td>
#       <td id="T_f73b8_row1_col2" class="data row1 col2" >4534047.9071</td>
#       <td id="T_f73b8_row1_col3" class="data row1 col3" >2025.0398</td>
#       <td id="T_f73b8_row1_col4" class="data row1 col4" >0.9527</td>
#       <td id="T_f73b8_row1_col5" class="data row1 col5" >0.0431</td>
#       <td id="T_f73b8_row1_col6" class="data row1 col6" >0.0330</td>
#       <td id="T_f73b8_row1_col7" class="data row1 col7" >0.1710</td>
#     </tr>
#     <tr>
#       <th id="T_f73b8_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_f73b8_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f73b8_row2_col1" class="data row2 col1" >1622.8655</td>
#       <td id="T_f73b8_row2_col2" class="data row2 col2" >4577693.8289</td>
#       <td id="T_f73b8_row2_col3" class="data row2 col3" >2046.1168</td>
#       <td id="T_f73b8_row2_col4" class="data row2 col4" >0.9520</td>
#       <td id="T_f73b8_row2_col5" class="data row2 col5" >0.0424</td>
#       <td id="T_f73b8_row2_col6" class="data row2 col6" >0.0339</td>
#       <td id="T_f73b8_row2_col7" class="data row2 col7" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_f73b8_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_f73b8_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_f73b8_row3_col1" class="data row3 col1" >1671.6607</td>
#       <td id="T_f73b8_row3_col2" class="data row3 col2" >4782286.8608</td>
#       <td id="T_f73b8_row3_col3" class="data row3 col3" >2103.2705</td>
#       <td id="T_f73b8_row3_col4" class="data row3 col4" >0.9501</td>
#       <td id="T_f73b8_row3_col5" class="data row3 col5" >0.0440</td>
#       <td id="T_f73b8_row3_col6" class="data row3 col6" >0.0349</td>
#       <td id="T_f73b8_row3_col7" class="data row3 col7" >0.0690</td>
#     </tr>
#     <tr>
#       <th id="T_f73b8_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_f73b8_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_f73b8_row4_col1" class="data row4 col1" >1678.0299</td>
#       <td id="T_f73b8_row4_col2" class="data row4 col2" >4809592.7576</td>
#       <td id="T_f73b8_row4_col3" class="data row4 col3" >2093.3086</td>
#       <td id="T_f73b8_row4_col4" class="data row4 col4" >0.9494</td>
#       <td id="T_f73b8_row4_col5" class="data row4 col5" >0.0443</td>
#       <td id="T_f73b8_row4_col6" class="data row4 col6" >0.0353</td>
#       <td id="T_f73b8_row4_col7" class="data row4 col7" >0.0370</td>
#     </tr>
#     <tr>
#       <th id="T_f73b8_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_f73b8_row5_col0" class="data row5 col0" >CatBoost Regressor</td>
#       <td id="T_f73b8_row5_col1" class="data row5 col1" >1690.5057</td>
#       <td id="T_f73b8_row5_col2" class="data row5 col2" >4867365.7536</td>
#       <td id="T_f73b8_row5_col3" class="data row5 col3" >2106.7683</td>
#       <td id="T_f73b8_row5_col4" class="data row5 col4" >0.9490</td>
#       <td id="T_f73b8_row5_col5" class="data row5 col5" >0.0446</td>
#       <td id="T_f73b8_row5_col6" class="data row5 col6" >0.0357</td>
#       <td id="T_f73b8_row5_col7" class="data row5 col7" >10.8240</td>
#     </tr>
#     <tr>
#       <th id="T_f73b8_level0_row6" class="row_heading level0 row6" >omp</th>
#       <td id="T_f73b8_row6_col0" class="data row6 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_f73b8_row6_col1" class="data row6 col1" >1725.4554</td>
#       <td id="T_f73b8_row6_col2" class="data row6 col2" >5222416.1068</td>
#       <t

# %%
modelo = tune_model(modelo, search_algorithm = "tpe", search_library = "optuna", optimize = metrica, n_iter = 10,
                    tuner_verbose = False, choose_better = True, verbose = True )
# Out:
# <style type="text/css">
# #T_8fa9d_row10_col0, #T_8fa9d_row10_col1, #T_8fa9d_row10_col2, #T_8fa9d_row10_col3, #T_8fa9d_row10_col4, #T_8fa9d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_
>0.0292</td>
#     </tr>
#     <tr>
#       <th id="T_8fa9d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8fa9d_row7_col0" class="data row7 col0" >1842.0765</td>
#       <td id="T_8fa9d_row7_col1" class="data row7 col1" >7954875.6047</td>
#       <td id="T_8fa9d_row7_col2" class="data row7 col2" >2820.4389</td>
#       <td id="T_8fa9d_row7_col3" class="data row7 col3" >0.9128</td>
#       <td id="T_8fa9d_row7_col4" class="data row7 col4" >0.0564</td>
#       <td id="T_8fa9d_row7_col5" class="data row7 col5" >0.0389</td>
#     </tr>
#     <tr>
#       <th id="T_8fa9d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8fa9d_row8_col0" class="data row8 col0" >1136.1549</td>
#       <td id="T_8fa9d_row8_col1" class="data row8 col1" >1984386.6480</td>
#       <td id="T_8fa9d_row8_col2" class="data row8 col2" >1408.6826</td>
#       <td id="T_8fa9d_row8_col3" class="data row8 col3" >0.9777</td>
#       <td id="T_8fa9d_row8_col4" class="data row8 col4" >0.0304</td>
#       <td id="T_8fa9d_row8_col5" class="data row8 col5" >0.0233</td>
#     </tr>
#     <tr>
#       <th id="T_8fa9d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8fa9d_row9_col0" class="data row9 col0" >2051.4815</td>
#       <td id="T_8fa9d_row9_col1" class="data row9 col1" >7496634.7433</td>
#       <td id="T_8fa9d_row9_col2" class="data row9 col2" >2737.9983</td>
#       <td id="T_8fa9d_row9_col3" class="data row9 col3" >0.9359</td>
#       <td id="T_8fa9d_row9_col4" class="data row9 col4" >0.0551</td>
#       <td id="T_8fa9d_row9_col5" class="data row9 col5" >0.0412</td>
#     </tr>
#     <tr>
#       <th id="T_8fa9d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_8fa9d_row10_col0" class="data row10 col0" >1552.5554</td>
#       <td id="T_8fa9d_row10_col1" class="data row10 col1" >4436751.7249</td>
#       <td id="T_8fa9d_row10_col2" class="data row10 col2" >2012.5790</td>
#       <td id="T_8fa9d_row10_col3" class="data row10 col3" >0.9530</td>
#       <td id="T_8fa9d_row10_col4" class="data row10 col4" >0.0425</td>
#       <td id="T_8fa9d_row10_col5" class="data row10 col5" >0.0328</td>
#     </tr>
#     <tr>
#       <th id="T_8fa9d_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_8fa9d_row11_col0" class="data row11 col0" >455.5445</td>
#       <td id="T_8fa9d_row11_col1" class="data row11 col1" >2548876.6534</td>
#       <td id="T_8fa9d_row11_col2" class="data row11 col2" >621.5124</td>
#       <td id="T_8fa9d_row11_col3" class="data row11 col3" >0.0264</td>
#       <td id="T_8fa9d_row11_col4" class="data row11 col4" >0.0116</td>
#       <td id="T_8fa9d_row11_col5" class="data row11 col5" >0.0088</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_modelo = finalize_model(modelo)

# %%
prediccion = predict_model(final_modelo, data = test)

# %%
import telepot

bot_token = '1653124784:AAFpL0qlC_ybadcbFX6jKagauRFpiFpSf1E'
chatID = '-1001701018194'

bot = telepot.Bot(bot_token)

# %%
from datetime import datetime

# %%
mensaje = "BTC : " + str(prediccion["Label"][0].round(2)) + " USD at " + str(datetime.today().strftime('%d-%m-%Y'))
print(mensaje)
# Out:
# BTC : 50323.83 USD at 07-12-2021

# %%
bot.sendMessage(chatID, mensaje)
# Out:
# {'message_id': 11,
#  'from': {'id': 1653124784,
#   'is_bot': True,
#   'first_name': 'JARVIS',
#   'username': 'JARVIS_Walkn_bot'},
#  'chat': {'id': -1001701018194,
#   'title': 'MoneyIsJustANumber',
#   'type': 'supergroup'},
#  'date': 1638907732,
#  'text': 'BTC : 50323.83 USD at 07-12-2021'}
